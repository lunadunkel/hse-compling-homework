# %% [markdown]
# # Домашнее задание № 3. Исправление опечаток

# %% [markdown]
# ## 1. Учет грамматики при оценке исправлений (3 балла)
#
# В последнюю итерацию алгоритма для генерации исправлений добавьте еще один компонент - учет грамматической информации. Частично она уже учитывается за счет языковой модели (вероятность предсказывается для словоформы), но такой подход ограничен из-за того, что модель не может ничего предсказать для словоформ, которых не было в обучающей выборке. Чтобы это исправить постройте еще одну "языковую модель" на грамматических тэгах:
# 1) Используя mystem или pymorphy, разметьте какой-нибудь корпус (например, кусок wiki из семинара) или воспользуйтесь уже размеченным корпусом (например, opencorpora)
# 2) соберите униграмные и биграмные статистики на уровне грамматических тэгов (например, вместо `задача важна` у вас будет биграм `S,жен,неод=им,ед A=ед,кр,жен`). Для простоты можете начать только с частеречных тэгов и добавить остальную информацию позже
# 3) напишите функцию, которая будет оценивать вероятность данного предложения на основе грамматической языковой модели (статистик из предыдущего шага). Функция должна сначала преобразовать текст в грамматические тэги, используя точно такой же подход, что использовался на шаге 1.
# 4) в функции correct_text_with_lm замените compute_sentence_proba на вашу новую функцию и прогоните получившийся алгоритм на данных
# 5) сравните предсказания с предсказанием изначального correct_text_with_lm, проверьте метрики и посмотрите на различие в ошибках и исправлениях, найдите несколько примеров отличий в предсказаниях этих подходов

# %%
# %pip install textdistance
# Out:
# Requirement already satisfied: textdistance in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (4.6.3)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import numpy as np
import textdistance
from string import punctuation
from collections import Counter
from pymystem3 import Mystem
from tqdm import tqdm
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances

# %%
morph_analyzer = Mystem(grammar_info=True, disambiguation=False, entire_input=False)

# %%
bad = open('sents_with_mistakes.txt', encoding='utf8').read().splitlines()
true = open('correct_sents.txt', encoding='utf8').read().splitlines()

# %%
def align_words(sent_1, sent_2):
    tokens_1 = sent_1.lower().split()
    tokens_2 = sent_2.lower().split()
    
    tokens_1 = [token.strip(punctuation) for token in tokens_1]
    tokens_2 = [token.strip(punctuation) for token in tokens_2]
    
    tokens_1 = [token for token in tokens_1 if token]
    tokens_2 = [token for token in tokens_2 if token]
    
    assert len(tokens_1) == len(tokens_2)
    
    return list(zip(tokens_1, tokens_2))

# %%
def grammar_info(sent):
    grs = morph_analyzer.analyze(sent)
    sent = [x['analysis'][0]['gr'] for x in grs if x['analysis']]
    return sent

def sentensize(text):
    return sent_tokenize(text)

def normalize(text):
    normalized_text = [re.sub("[«»]+", '', word.strip(punctuation)) for word in text.split()]
    normalized_text = [word.lower() for word in normalized_text if word]
    return normalized_text

def ngrammer(tokens, n=2):
    ngrams = []
    for i in range(0,len(tokens)-n+1):
        ngrams.append(' '.join(tokens[i:i+n]))
    return ngrams

def get_statistics(sentences):
    unigrams, bigrams = Counter(), Counter()
    for sent in sentences:
        for i in range(len(sent)):
            unigrams[sent[i]] += 1
            if i>=1:
                bigrams[(sent[i-1], sent[i])] += 1
    return unigrams, bigrams


def analyze_data(corpus, gr_feats=False):
    sentences = sentensize(corpus)
    if gr_feats:
        sentences_w_gram_feats = [grammar_info(sent) for sent in sentences]
        unigrams, bigrams = get_statistics(sentences_w_gram_feats)
    else:
        tokenized_sentences = [normalize(sent) for sent in sentences]
        unigrams, bigrams = get_statistics(tokenized_sentences)
    return unigrams, bigrams

# %%
# основной корпус
corpus = open('wiki_data.txt', encoding='utf8').read()
# словарь
vocab = Counter(re.findall(r'\w+', corpus.lower()))
# размер словаря
N = sum(vocab.values())
id2word = {i:word for i, word in enumerate(vocab.keys())}

# %%
# статистика по грам фичам
unigrams, bigrams = analyze_data(corpus, gr_feats=True)

# %%
unigrams['S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)']
# Out:
# 105289

# %%
# статистика по обычным словам
regular_unigrams, regular_bigrams = analyze_data(corpus)

# %%
# функция вероятности для слова
def P(word, N=N):
    return vocab[word] / N

# %%
def predict_mistaken(word, vocab):
    return 0 if word in vocab else 1

def get_closest_match_vec(text, X, vec, topn=20):
    v = vec.transform([text])
    similarities = cosine_distances(v, X)[0]
    topn = similarities.argsort()[:topn] 
    
    return [(id2word[top], similarities[top]) for top in topn]

def get_closest_match_with_metric(text, lookup, topn=20, metric=textdistance.levenshtein):
    similarities = Counter()
    for word in lookup:
        similarities[word] = metric.similarity(text, word) 
    
    return similarities.most_common(topn)

def get_closest_hybrid_match(text, X, vec, topn=3, metric=textdistance.damerau_levenshtein):
    candidates = get_closest_match_vec(text, X, vec, topn*4)
    lookup = [cand[0] for cand in candidates]
    closest = get_closest_match_with_metric(text, lookup, topn, metric=metric)

    
    return closest

# %%
def compute_sentence_proba_gram(text, unigram_counts, bigram_counts, smoothing=2e-5):
    tags = ["<START>"] + grammar_info(text) + ["<END>"]
    prob = 0.0
    for i in range(1, len(tags)):
        t1, t2 = tags[i - 1], tags[i]
        bigram = (t1, t2)

        if t1 in unigram_counts and bigram in bigram_counts:
            p = bigram_counts[bigram] / unigram_counts[t1]
        else:
            p = smoothing
        prob += np.log(p)
    return prob

# %%
def calculate_metrics(true, actual, predicted):
    correct = 0
    total = 0
    total_mistaken = 0
    mistaken_fixed = 0
    total_correct = 0
    correct_broken = 0

    for i in range(len(true)):
        t, a, p = true[i], actual[i], predicted[i]
        if t == p:
            correct += 1
        total += 1
        
        if t == a:
            total_correct += 1
            if t != p:
                correct_broken += 1
        else:
            total_mistaken += 1
            if t == p:
                mistaken_fixed += 1

    return {"total_accuracy": correct/total,
            "fixed_mistakes": mistaken_fixed/total_mistaken,
            "broken_correct_words": correct_broken/total_correct}

# %%
def compute_sentence_proba(text, word_counts, bigram_counts):
    prob = 0
    tokens = normalize(text)
    for ngram in ngrammer(['<start>'] + tokens + ['<end>']):
        word1, word2 = ngram.split()
        if word1 in word_counts and ngram in bigram_counts:
            prob += np.log(bigram_counts[ngram]/word_counts[word1])
        else:
            prob += np.log(2e-5)
    
    return prob

# %%
vec = CountVectorizer(analyzer='char', max_features=10000, ngram_range=(1,3))
X = vec.fit_transform(vocab)

# %%
import itertools

def correct_text_with_lm(text, use_gram=True):
    tokens = normalize(text)
    correction_sets = [] 
    
    for word in tokens:
        if predict_mistaken(word, vocab):
            preds = get_closest_hybrid_match(word, X, vec)
            preds = [p[0] for p in preds]
            correction_sets.append(preds)
        else:
            correction_sets.append([word])

    possible_sentences = [" ".join(words) 
                          for words in itertools.product(*correction_sets)]

    if use_gram:
        scorer = lambda s: compute_sentence_proba_gram(s, unigrams, bigrams)
    else:
        scorer = lambda s: compute_sentence_proba(s, regular_unigrams, regular_bigrams)

    best_sentence = max(possible_sentences, key=scorer)
    return best_sentence

# %%
y_true = []
y_actual = []
y_preds = []

for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])
    corrected = correct_text_with_lm(bad[i]).split()
    
    for i in range(len(word_pairs)):
        true_word = word_pairs[i][0]
        actual_word = word_pairs[i][1]
        pred = corrected[i]
            
        y_preds.append(pred)
        y_true.append(true_word)
        y_actual.append(actual_word)
# Out:
# 100%|██████████| 915/915 [08:59<00:00,  1.70it/s]

# %%
metrics = calculate_metrics(y_true, y_actual, y_preds)
metrics
# Out:
# {'total_accuracy': 0.8364182091045522,
#  'fixed_mistakes': 0.3392857142857143,
#  'broken_correct_words': 0.09004249454461927}

# %%
y_true_reg = []
y_actual_reg = []
y_preds_reg = []

for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])
    corrected = correct_text_with_lm(bad[i], use_gram=False).split()
    
    for i in range(len(word_pairs)):
        true_word = word_pairs[i][0]
        actual_word = word_pairs[i][1]
        pred = corrected[i]
            
        y_preds_reg.append(pred)
        y_true_reg.append(true_word)
        y_actual_reg.append(actual_word)
# Out:
# 100%|██████████| 915/915 [07:41<00:00,  1.98it/s]

# %%
regular_metrics = calculate_metrics(y_true_reg, y_actual_reg, y_preds_reg)
regular_metrics
# Out:
# {'total_accuracy': 0.8467233616808404,
#  'fixed_mistakes': 0.4192546583850932,
#  'broken_correct_words': 0.09004249454461927}

# %%
print('Слова, где обе ошиблись, но по-разному')
i = 0
for true_pred, gram_pred, actual_pred, reg_pred in zip(y_true, y_preds, y_actual, y_preds_reg):
    if i == 15:
        break
    if true_pred != gram_pred and true_pred != reg_pred and reg_pred != gram_pred:
        i += 1
        s = ''
        print("ТИП ОШИБКИ:", end="\t")
        if actual_pred == true_pred:
            s = 'FALSE POSITIVE\t(слово не нуждалось в исправлении)'
        else:
            s = 'НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ'
        print(s, end='\n\n')
        print(f"Реальное слово: {actual_pred}\t\\\tКорректное исправление: {true_pred:}", end='\n\n')
        print("Предсказания:")
        print(f"\t - Стандартная функция: {reg_pred}")
        print(f"\t - Функция на грамматических признаках: {gram_pred}", end='\n\n')
# Out:
# Слова, где обе ошиблись, но по-разному
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: симпатичнейшое	\	Корректное исправление: симпатичнейшее
#
# Предсказания:
# 	 - Стандартная функция: симпатичнее
# 	 - Функция на грамматических признаках: симпатичной
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: шпионское	\	Корректное исправление: шпионское
#
# Предсказания:
# 	 - Стандартная функция: шпионско
# 	 - Функция на грамматических признаках: шпионской
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: гламурный	\	Корректное исправление: гламурный
#
# Предсказания:
# 	 - Стандартная функция: гламурным
# 	 - Функция на грамматических признаках: гламурные
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: услышанная	\	Корректное исправление: услышанная
#
# Предсказания:
# 	 - Стандартная функция: услышанным
# 	 - Функция на грамматических признаках: услышанные
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: пояним	\	Корректное исправление: поясним
#
# Предсказания:
# 	 - Стандартная функция: стояниями
# 	 - Функция на грамматических признаках: поднимания
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: нащщот	\	Корректное исправление: насчет
#
# Предсказания:
# 	 - Стандартная функция: оснащают
# 	 - Функция на грамматических признаках: нащокина
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: ящека	\	Корректное исправление: ящика
#
# Предсказания:
# 	 - Стандартная функция: щека
# 	 - Функция на грамматических признаках: яцека
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: рите	\	Корректное исправление: рите
#
# Предсказания:
# 	 - Стандартная функция: ритер
# 	 - Функция на грамматических признаках: иврите
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: пытаюсь	\	Корректное исправление: пытаюсь
#
# Предсказания:
# 	 - Стандартная функция: пытаются
# 	 - Функция на грамматических признаках: пыталась
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: дубраве	\	Корректное исправление: дубраве
#
# Предсказания:
# 	 - Стандартная функция: дубрав
# 	 - Функция на грамматических признаках: дубравы
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: билетным	\	Корректное исправление: билетным
#
# Предсказания:
# 	 - Стандартная функция: билетные
# 	 - Функция на грамматических признаках: билетных
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: чтото	\	Корректное исправление: что-то
#
# Предсказания:
# 	 - Стандартная функция: частотой
# 	 - Функция на грамматических признаках: тото
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: капулетти	\	Корректное исправление: капулетти
#
# Предсказания:
# 	 - Стандартная функция: катапультируется
# 	 - Функция на грамматических признаках: паулетты
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: кормилицу	\	Корректное исправление: кормилицу
#
# Предсказания:
# 	 - Стандартная функция: кормилица
# 	 - Функция на грамматических признаках: кормили
#
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: оплеух	\	Корректное исправление: оплеух
#
# Предсказания:
# 	 - Стандартная функция: утоплено
# 	 - Функция на грамматических признаках: доплера

# %% [markdown]
# Из интересного: модели пытаются корректные слова исправить, когда они в каком-то падеже (не в номинативе), глаголы в менее, видимо, частотных лице-численных формах, и в принципе редкие солова. СМ:
#
# ```Реальное слово: билетным	\	Корректное исправление: билетным
#
# Предсказания:
# 	 - Стандартная функция: билетные
# 	 - Функция на грамматических признаках: билетных
#
# Реальное слово: капулетти	\	Корректное исправление: капулетти
#
# Предсказания:
# 	 - Стандартная функция: катапультируется
# 	 - Функция на грамматических признаках: паулетты

# %%
print('Слова, где ошиблась грамматическая')
i = 0
for true_pred, gram_pred, actual_pred, reg_pred in zip(y_true, y_preds, y_actual, y_preds_reg):
    if i == 15:
        break
    if true_pred != gram_pred and true_pred == reg_pred:
        i += 1
        s = ''
        print("ТИП ОШИБКИ:", end="\t")
        if actual_pred == true_pred:
            s = 'FALSE POSITIVE\t(слово не нуждалось в исправлении)'
        else:
            s = 'НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ'
        print(s, end='\n\n')
        print(f"Реальное слово: {actual_pred}\t\\\tКорректное исправление: {true_pred:}", end='\n\n')
        print("Предсказания:")
        print(f"\t - Стандартная функция: {reg_pred}")
        print(f"\t - Функция на грамматических признаках: {gram_pred}", end='\n\n')
# Out:
# Слова, где ошиблась грамматическая
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: предлагю	\	Корректное исправление: предлагаю
#
# Предсказания:
# 	 - Стандартная функция: предлагаю
# 	 - Функция на грамматических признаках: предлагают
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: выходгых	\	Корректное исправление: выходных
#
# Предсказания:
# 	 - Стандартная функция: выходных
# 	 - Функция на грамматических признаках: выходы
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: компютерная	\	Корректное исправление: компьютерная
#
# Предсказания:
# 	 - Стандартная функция: компьютерная
# 	 - Функция на грамматических признаках: суперкомпьютерная
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: отвественность	\	Корректное исправление: ответственность
#
# Предсказания:
# 	 - Стандартная функция: ответственность
# 	 - Функция на грамматических признаках: ответственностью
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: коментариев	\	Корректное исправление: комментариев
#
# Предсказания:
# 	 - Стандартная функция: комментариев
# 	 - Функция на грамматических признаках: комментарием
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: ввеселились	\	Корректное исправление: веселились
#
# Предсказания:
# 	 - Стандартная функция: веселились
# 	 - Функция на грамматических признаках: вселились
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: хочеться	\	Корректное исправление: хочется
#
# Предсказания:
# 	 - Стандартная функция: хочется
# 	 - Функция на грамматических признаках: одеться
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: расщифровать	\	Корректное исправление: расшифровать
#
# Предсказания:
# 	 - Стандартная функция: расшифровать
# 	 - Функция на грамматических признаках: расшифровывать
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: приветствутется	\	Корректное исправление: приветствуется
#
# Предсказания:
# 	 - Стандартная функция: приветствуется
# 	 - Функция на грамматических признаках: приветствует
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: сочуствующие	\	Корректное исправление: сочувствующие
#
# Предсказания:
# 	 - Стандартная функция: сочувствующие
# 	 - Функция на грамматических признаках: сочувствующими
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: естесственно	\	Корректное исправление: естественно
#
# Предсказания:
# 	 - Стандартная функция: естественно
# 	 - Функция на грамматических признаках: естественной
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: основыные	\	Корректное исправление: основные
#
# Предсказания:
# 	 - Стандартная функция: основные
# 	 - Функция на грамматических признаках: основанные
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: кстате	\	Корректное исправление: кстати
#
# Предсказания:
# 	 - Стандартная функция: кстати
# 	 - Функция на грамматических признаках: некстати
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: проичитал	\	Корректное исправление: прочитал
#
# Предсказания:
# 	 - Стандартная функция: прочитал
# 	 - Функция на грамматических признаках: просчитал
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: кстате	\	Корректное исправление: кстати
#
# Предсказания:
# 	 - Стандартная функция: кстати
# 	 - Функция на грамматических признаках: некстати

# %%
print('Слова, где ошиблась стандартная')
i = 0
for true_pred, gram_pred, actual_pred, reg_pred in zip(y_true, y_preds, y_actual, y_preds_reg):
    if i == 15:
        break
    if true_pred == gram_pred and true_pred != reg_pred:
        i += 1
        s = ''
        print("ТИП ОШИБКИ:", end="\t")
        if actual_pred == true_pred:
            s = 'FALSE POSITIVE\t(слово не нуждалось в исправлении)'
        else:
            s = 'НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ'
        print(s, end='\n\n')
        print(f"Реальное слово: {actual_pred}\t\\\tКорректное исправление: {true_pred:}", end='\n\n')
        print("Предсказания:")
        print(f"\t - Стандартная функция: {reg_pred}")
        print(f"\t - Функция на грамматических признаках: {gram_pred}", end='\n\n')
# Out:
# Слова, где ошиблась стандартная
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: баръер	\	Корректное исправление: барьер
#
# Предсказания:
# 	 - Стандартная функция: барбер
# 	 - Функция на грамматических признаках: барьер
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: ооочень	\	Корректное исправление: очень
#
# Предсказания:
# 	 - Стандартная функция: сорочень
# 	 - Функция на грамматических признаках: очень
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: оооочень	\	Корректное исправление: очень
#
# Предсказания:
# 	 - Стандартная функция: сорочень
# 	 - Функция на грамматических признаках: очень
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: получаеться	\	Корректное исправление: получается
#
# Предсказания:
# 	 - Стандартная функция: получаться
# 	 - Функция на грамматических признаках: получается
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: движениие	\	Корректное исправление: движение
#
# Предсказания:
# 	 - Стандартная функция: движении
# 	 - Функция на грамматических признаках: движение
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: удалитъ	\	Корректное исправление: удалить
#
# Предсказания:
# 	 - Стандартная функция: удалите
# 	 - Функция на грамматических признаках: удалить
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: потреяна	\	Корректное исправление: потеряна
#
# Предсказания:
# 	 - Стандартная функция: потребная
# 	 - Функция на грамматических признаках: потеряна
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: убрть	\	Корректное исправление: убрать
#
# Предсказания:
# 	 - Стандартная функция: уборть
# 	 - Функция на грамматических признаках: убрать
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: оооочень	\	Корректное исправление: очень
#
# Предсказания:
# 	 - Стандартная функция: сорочень
# 	 - Функция на грамматических признаках: очень
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: получаеться	\	Корректное исправление: получается
#
# Предсказания:
# 	 - Стандартная функция: получаться
# 	 - Функция на грамматических признаках: получается
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: потоиу	\	Корректное исправление: потому
#
# Предсказания:
# 	 - Стандартная функция: потоку
# 	 - Функция на грамматических признаках: потому
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: сапсибо	\	Корректное исправление: спасибо
#
# Предсказания:
# 	 - Стандартная функция: запсибом
# 	 - Функция на грамматических признаках: спасибо
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: оочень	\	Корректное исправление: очень
#
# Предсказания:
# 	 - Стандартная функция: сорочень
# 	 - Функция на грамматических признаках: очень
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: переодически	\	Корректное исправление: периодически
#
# Предсказания:
# 	 - Стандартная функция: периодические
# 	 - Функция на грамматических признаках: периодически
#
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: переодически	\	Корректное исправление: периодически
#
# Предсказания:
# 	 - Стандартная функция: периодические
# 	 - Функция на грамматических признаках: периодически

# %%
print('Примеры слов, где произошла "гиперкоррекция" у обеих моделей (одинаковая)')
hyper_reg = []
hyper_gram = []
i = 0
for true_pred, gram_pred, actual_pred, reg_pred in zip(y_true, y_preds, y_actual, y_preds_reg):
    if i == 15:
        break
    if true_pred != gram_pred and true_pred != reg_pred:
        s = ''
        if actual_pred == true_pred:
            i += 1
            hyper_reg.append((true_pred, reg_pred))
            hyper_gram.append((true_pred, gram_pred))

intersect = set(hyper_reg).intersection(set(hyper_gram))
print(f"Пересечение: {len(intersect)}")
for word in intersect:
    print('Слово: {:>30}\t'.format(word[0]), end='')
    print('{:^10}'.format('Исправление'), end="")
    print('{:>20}'.format(word[1]))
# Out:
# Примеры слов, где произошла "гиперкоррекция" у обеих моделей (одинаковая)
# Пересечение: 9
# Слово:                       люминала	Исправление            номинала
# Слово:           дорожно-транспортных	Исправление    автотранспортных
# Слово:                         снятся	Исправление           выяснятся
# Слово:                       почте.ру	Исправление               почте
# Слово:                     superheadz	Исправление       superspeedway
# Слово:                         сетуют	Исправление            советуют
# Слово:                         язычки	Исправление            язычники
# Слово:          аварийно-спасательных	Исправление   горноспасательных
# Слово:                           clap	Исправление             clapier

# %% [markdown]
# ## 2.  Symspell (5 баллов)

# %% [markdown]
# Реализуйте алгоритм Symspell. Он похож на алгоритм Норвига, но проще и быстрее. Он основан только на одной операции - удалении символа. Описание алгоритма по шагам:
#
# 1) Составляется словарь правильных слов
# 2) На основе словаря правильных слов составляется словарь удалений - для каждого правильного слова создаются все варианты удалений и создается словарь, где ключ - слово с удалением, а значение - правильное слово  (обратите внимание, что для одного удаления может быть несколько правильных слов!)
# 3) При исправлении слова с опечаткой сначала само слово проверятся по словарю удаления, а затем для этого слова генерируются все варианты удалений, и каждый вариант проверяется по словарю удалений. Если в словаре удалений таким образом находится совпадение, то соответствующее ему правильное слово становится исправлением.
# Если совпадений несколько, то выбирается наиболее вероятное правильное слово
#
#
# Оцените качество полученного алгоритма теми же тремя метриками.

# %%
import re
from collections import defaultdict, Counter

# %%
def generate_deletes_step(word, distance, max_distance, deletes):
    if distance > max_distance:
        return

    for i in range(len(word)):
        deleted = word[:i] + word[i+1:]
        if deleted not in deletes:
            deletes.add(deleted)
            generate_deletes_step(deleted, distance + 1, max_distance, deletes)


def generate_deletes(word, max_distance=MAX_EDIT_DISTANCE):
    deletes = set()
    generate_deletes_step(word, 1, max_distance, deletes)
    return deletes

# %%
def build_dictionary(corpus, max_distance=MAX_EDIT_DISTANCE):
    words = normalize(corpus)
    for w in words:
        w = w.lower()
        dictionary[w] += 1

    for w in dictionary:
        for d in generate_deletes(w, max_distance):
            deletion_index[d].append(w)

# %%
def symspell_candidates(input_word, dictionary, deletion_index, max_distance=MAX_EDIT_DISTANCE):
    candidates = set()

    if input_word in dictionary:
        candidates.add(input_word)
        return candidates 

    if input_word in deletion_index:
        candidates.update(deletion_index[input_word])

    for d in generate_deletes(input_word, max_distance):
        if d in deletion_index:
            candidates.update(deletion_index[d])

    return candidates

# %%
def rank_candidates(input_word, candidates, dictionary):
    scored = []
    for cand in candidates:
        d = textdistance.levenshtein(input_word, cand)
        freq = dictionary[cand]
        scored.append((cand, d, freq))
    
    # сортировка по расстоянию, потом по частоте в словаре
    scored.sort(key=lambda x: (x[1], -x[2], x[0]))
    return scored

# %%
def symspell_best(input_word, candidates, dictionary):
    ranked = rank_candidates(input_word, candidates, dictionary)
    return ranked[0][0] if ranked else None

# %%
def correct_text_with_symspell(text, vocab, deletion_index, max_distance=2):
    tokens = normalize(text)
    corrected_tokens = []

    for word in tokens:
        if predict_mistaken(word, vocab):
            candidates = symspell_candidates(word, vocab, deletion_index, max_distance=max_distance)
            correction = symspell_best(word, candidates, vocab)
            corrected_tokens.append(correction if correction else word)
        else:
            corrected_tokens.append(word)

    return " ".join(corrected_tokens)

# %%
corpus = open('wiki_data.txt', encoding='utf8').read()

# словарь
dictionary = Counter()
# словарь удалений
deletion_index = defaultdict(list)

build_dictionary(corpus)

# %%
DELETION_INDEX = deletion_index
DICTIONARY = dictionary

# %%
y_true = []
y_actual = []
y_preds = []

for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])

    corrected = correct_text_with_symspell(bad[i], dictionary, deletion_index).split()

    for j in range(len(word_pairs)):
        true_word = word_pairs[j][0]
        actual_word = word_pairs[j][1]
        pred = corrected[j]

        y_true.append(true_word)
        y_actual.append(actual_word)
        y_preds.append(pred)
# Out:
# 100%|██████████| 915/915 [00:00<00:00, 1429.80it/s]

# %%
metrics = calculate_metrics(y_true, y_actual, y_preds)
metrics
# Out:
# {'total_accuracy': 0.870935467733867,
#  'fixed_mistakes': 0.5170807453416149,
#  'broken_correct_words': 0.07671988055587459}

# %%
print('Слова, где ошиблась модель')
i = 0
for true_pred, model_pred, actual_pred in zip(y_true, y_preds, y_actual):
    if i == 15:
        break
    if true_pred != model_pred:
        i += 1
        s = ''
        print("ТИП ОШИБКИ:", end="\t")
        if actual_pred == true_pred:
            s = 'FALSE POSITIVE\t(слово не нуждалось в исправлении)'
        else:
            s = 'НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ'
        print(s, end='\n\n')
        print(f"Реальное слово: {actual_pred}\t\\\tКорректное исправление: {true_pred:}", end='\n\n')
        print(f"Предсказание: {model_pred}")
# Out:
# Слова, где ошиблась модель
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: симпатичнейшое	\	Корректное исправление: симпатичнейшее
#
# Предсказание: симпатичнейшое
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: шпионское	\	Корректное исправление: шпионское
#
# Предсказание: шпионской
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: гламурный	\	Корректное исправление: гламурный
#
# Предсказание: гламурным
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: clap	\	Корректное исправление: clap
#
# Предсказание: cap
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: опофеозом	\	Корректное исправление: апофеозом
#
# Предсказание: опофеозом
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: услышанная	\	Корректное исправление: услышанная
#
# Предсказание: услышанное
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: пояним	\	Корректное исправление: поясним
#
# Предсказание: одним
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: язычки	\	Корректное исправление: язычки
#
# Предсказание: языки
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: оччччень	\	Корректное исправление: очень
#
# Предсказание: оччччень
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: нащщот	\	Корректное исправление: насчет
#
# Предсказание: нагота
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: сетуют	\	Корректное исправление: сетуют
#
# Предсказание: сетует
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: основая	\	Корректное исправление: основная
#
# Предсказание: основан
# ТИП ОШИБКИ:	FALSE POSITIVE	(слово не нуждалось в исправлении)
#
# Реальное слово: дорожно-транспортных	\	Корректное исправление: дорожно-транспортных
#
# Предсказание: дорожно-транспортные
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: вобщем	\	Корректное исправление: в
#
# Предсказание: общем
# ТИП ОШИБКИ:	НЕПРАВИЛЬНОЕ ИСПРАВЛЕНИЕ
#
# Реальное слово: как	\	Корректное исправление: общем
#
# Предсказание: как

# %% [markdown]
# # Задание 3 (2 балла)
#
# Используя любой из алгоритмов из семинара или домашки, детально проанализируйте получаемые ошибки. Улучшите алгоритм так, чтобы исправить ошибки. Улучшения в алгоритме должны быть общими, не привязанными к конкретным словам (например, словарь исключений не будет считаться). За каждое улучшение, которое исправляет 5+ ошибок вы получите 0.5 балла (максимум 2 в целом)

# %%
for true_pred, model_pred, actual_pred in zip(y_true, y_preds, y_actual):
    if true_pred != model_pred:
        print(f"Реальное слово: {actual_pred}\t\\\tКорректное исправление: {true_pred:}")
        print(f"Предсказание: {model_pred}", end='\n\n')
# Out:
# Реальное слово: симпатичнейшое	\	Корректное исправление: симпатичнейшее
# Предсказание: симпатичнейшое
#
# Реальное слово: шпионское	\	Корректное исправление: шпионское
# Предсказание: шпионской
#
# Реальное слово: гламурный	\	Корректное исправление: гламурный
# Предсказание: гламурным
#
# Реальное слово: clap	\	Корректное исправление: clap
# Предсказание: cap
#
# Реальное слово: опофеозом	\	Корректное исправление: апофеозом
# Предсказание: опофеозом
#
# Реальное слово: услышанная	\	Корректное исправление: услышанная
# Предсказание: услышанное
#
# Реальное слово: пояним	\	Корректное исправление: поясним
# Предсказание: одним
#
# Реальное слово: язычки	\	Корректное исправление: язычки
# Предсказание: языки
#
# Реальное слово: оччччень	\	Корректное исправление: очень
# Предсказание: оччччень
#
# Реальное слово: нащщот	\	Корректное исправление: насчет
# Предсказание: нагота
#
# Реальное слово: сетуют	\	Корректное исправление: сетуют
# Предсказание: сетует
#
# Реальное слово: основая	\	Корректное исправление: основная
# Предсказание: основан
#
# Реальное слово: дорожно-транспортных	\	Корректное исправление: дорожно-транспортных
# Предсказание: дорожно-транспортные
#
# Реальное слово: вобщем	\	Корректное исправление: в
# Предсказание: общем
#
# Реальное слово: как	\	Корректное исправление: общем
# Предсказание: как
#
# Реальное слово: вы	\	Корректное исправление: как
# Предсказание: вы
#
# Реальное слово: знаете	\	Корректное исправление: вы
# Предсказание: знаете
#
# Реальное слово: из	\	Корректное исправление: знаете
# Предсказание: из
#
# Реальное слово: моего	\	Корректное исправление: из
# Предсказание: моего
#
# Реальное слово: не	\	Корректное исправление: моего
# Предсказание: не
#
# Реальное слово: давнего	\	Корректное исправление: недавнего
# Предсказание: давнего
#
# Реальное слово: почте.ру	\	Корректное исправление: почте.ру
# Предсказание: портеру
#
# Реальное слово: рите	\	Корректное исправление: рите
# Предсказание: риме
#
# Реальное слово: снятся	\	Корректное исправление: снятся
# Предсказание: снялся
#
# Реальное слово: патаму	\	Корректное исправление: потому
# Предсказание: панаму
#
# Реальное слово: шта	\	Корректное исправление: что
# Предсказание: эта
#
# Реальное слово: пытаюсь	\	Корректное исправление: пытаюсь
# Предсказание: пытаясь
#
# Реальное слово: дубраве	\	Корректное исправление: дубраве
# Предсказание: дубрава
#
# Реальное слово: люминала	\	Корректное исправление: люминала
# Предсказание: номинала
#
# Реальное слово: поффтыкав	\	Корректное исправление: повтыкав
# Предсказание: поффтыкав
#
# Реальное слово: билетным	\	Корректное исправление: билетным
# Предсказание: билетные
#
# Реальное слово: кассам	\	Корректное исправление: кассам
# Предсказание: классам
#
# Реальное слово: соре	\	Корректное исправление: ссоре
# Предсказание: соре
#
# Реальное слово: выговаривает	\	Корректное исправление: выговаривает
# Предсказание: уговаривает
#
# Реальное слово: кредиток	\	Корректное исправление: кредиток
# Предсказание: кредитов
#
# Реальное слово: кормилицу	\	Корректное исправление: кормилицу
# Предсказание: кормилица
#
# Реальное слово: молодеж	\	Корректное исправление: молодежь
# Предсказание: молодеж
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: вешать	\	Корректное исправление: навешать
# Предсказание: вешать
#
# Реальное слово: оплеух	\	Корректное исправление: оплеух
# Предсказание: плену
#
# Реальное слово: пивоварах	\	Корректное исправление: пивоварах
# Предсказание: пивовара
#
# Реальное слово: эт	\	Корректное исправление: это
# Предсказание: эт
#
# Реальное слово: канешна	\	Корректное исправление: конечно
# Предсказание: кантона
#
# Реальное слово: зажог	\	Корректное исправление: зажег
# Предсказание: залог
#
# Реальное слово: павзрослому	\	Корректное исправление: по-взрослому
# Предсказание: павзрослому
#
# Реальное слово: прыщами	\	Корректное исправление: прыщами
# Предсказание: правами
#
# Реальное слово: слег	\	Корректное исправление: слег
# Предсказание: олег
#
# Реальное слово: ветрянка	\	Корректное исправление: ветрянка
# Предсказание: ветряка
#
# Реальное слово: малолетнии	\	Корректное исправление: малолетние
# Предсказание: малолетний
#
# Реальное слово: наркоманы	\	Корректное исправление: наркоманы
# Предсказание: наркомана
#
# Реальное слово: хихикать	\	Корректное исправление: хихикать
# Предсказание: химикаты
#
# Реальное слово: молодеж	\	Корректное исправление: молодежь
# Предсказание: молодеж
#
# Реальное слово: ощушаю	\	Корректное исправление: ощущаю
# Предсказание: ощущал
#
# Реальное слово: монголойдом	\	Корректное исправление: монголоидом
# Предсказание: монголойдом
#
# Реальное слово: молчала	\	Корректное исправление: молчала
# Предсказание: молчал
#
# Реальное слово: молчю	\	Корректное исправление: молчу
# Предсказание: молча
#
# Реальное слово: триатлон	\	Корректное исправление: триатлон
# Предсказание: триатлону
#
# Реальное слово: сашкой	\	Корректное исправление: сашкой
# Предсказание: самкой
#
# Реальное слово: плоскостопых	\	Корректное исправление: плоскостопых
# Предсказание: плоскостных
#
# Реальное слово: обълись	\	Корректное исправление: объелись
# Предсказание: обелиск
#
# Реальное слово: распрашивая	\	Корректное исправление: расспрашивая
# Предсказание: раскрашивая
#
# Реальное слово: зубодробительня	\	Корректное исправление: зубодробительная
# Предсказание: зубодробительня
#
# Реальное слово: гребенка	\	Корректное исправление: гребенка
# Предсказание: ребенка
#
# Реальное слово: каааак	\	Корректное исправление: как
# Предсказание: казак
#
# Реальное слово: изводить	\	Корректное исправление: изводить
# Предсказание: взводить
#
# Реальное слово: писмена	\	Корректное исправление: письмена
# Предсказание: пимена
#
# Реальное слово: дороговато	\	Корректное исправление: дороговато
# Предсказание: роговатое
#
# Реальное слово: штучка	\	Корректное исправление: штучка
# Предсказание: штучки
#
# Реальное слово: самойто	\	Корректное исправление: самой-то
# Предсказание: самойло
#
# Реальное слово: тул	\	Корректное исправление: тут
# Предсказание: тул
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: тока	\	Корректное исправление: только
# Предсказание: тока
#
# Реальное слово: навернео	\	Корректное исправление: наверное
# Предсказание: наверно
#
# Реальное слово: мечталось	\	Корректное исправление: мечталось
# Предсказание: металась
#
# Реальное слово: сынишке	\	Корректное исправление: сынишке
# Предсказание: сынишка
#
# Реальное слово: покорми	\	Корректное исправление: покорми
# Предсказание: покоями
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: доделала	\	Корректное исправление: доделала
# Предсказание: сделала
#
# Реальное слово: яся	\	Корректное исправление: яся
# Предсказание: вся
#
# Реальное слово: стараюсь	\	Корректное исправление: стараюсь
# Предсказание: стараясь
#
# Реальное слово: озаботил	\	Корректное исправление: озаботил
# Предсказание: заботила
#
# Реальное слово: никада	\	Корректное исправление: никогда
# Предсказание: никуда
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: симаатическая	\	Корректное исправление: симпатическая
# Предсказание: семантическая
#
# Реальное слово: потовые	\	Корректное исправление: потовые
# Предсказание: почтовые
#
# Реальное слово: слюнные	\	Корректное исправление: слюнные
# Предсказание: слюнных
#
# Реальное слово: радовала	\	Корректное исправление: радовала
# Предсказание: радовало
#
# Реальное слово: варикоза	\	Корректное исправление: варикоза
# Предсказание: варикапа
#
# Реальное слово: рассчете	\	Корректное исправление: расчете
# Предсказание: рассвете
#
# Реальное слово: купим	\	Корректное исправление: купим
# Предсказание: купил
#
# Реальное слово: пойдем	\	Корректное исправление: пойдем
# Предсказание: пойдет
#
# Реальное слово: navision	\	Корректное исправление: navision
# Предсказание: division
#
# Реальное слово: axapta	\	Корректное исправление: axapta
# Предсказание: alata
#
# Реальное слово: расжился	\	Корректное исправление: разжился
# Предсказание: разбился
#
# Реальное слово: сабжа	\	Корректное исправление: сабжа
# Предсказание: саба
#
# Реальное слово: обезумевшая	\	Корректное исправление: обезумевшая
# Предсказание: обезумевший
#
# Реальное слово: раскидала	\	Корректное исправление: раскидала
# Предсказание: раскидал
#
# Реальное слово: пользоваццо	\	Корректное исправление: пользоваться
# Предсказание: пользоваццо
#
# Реальное слово: бредовую	\	Корректное исправление: бредовую
# Предсказание: бедовую
#
# Реальное слово: доев	\	Корректное исправление: доев
# Предсказание: боев
#
# Реальное слово: покатавшись	\	Корректное исправление: покатавшись
# Предсказание: оказавшись
#
# Реальное слово: креатифф	\	Корректное исправление: креатив
# Предсказание: крещатик
#
# Реальное слово: экономикса	\	Корректное исправление: экономикса
# Предсказание: экономика
#
# Реальное слово: челка	\	Корректное исправление: челка
# Предсказание: белка
#
# Реальное слово: отросла	\	Корректное исправление: отросла
# Предсказание: обросла
#
# Реальное слово: стричься	\	Корректное исправление: стричься
# Предсказание: строиться
#
# Реальное слово: однимает	\	Корректное исправление: обнимает
# Предсказание: поднимает
#
# Реальное слово: эриды	\	Корректное исправление: эриды
# Предсказание: фриды
#
# Реальное слово: правила	\	Корректное исправление: правило
# Предсказание: правила
#
# Реальное слово: даешь	\	Корректное исправление: даешь
# Предсказание: дашь
#
# Реальное слово: удивленные	\	Корректное исправление: удивленные
# Предсказание: удивленный
#
# Реальное слово: нисхождении	\	Корректное исправление: нисхождении
# Предсказание: нисхождение
#
# Реальное слово: нмного	\	Корректное исправление: немного
# Предсказание: много
#
# Реальное слово: открыывю	\	Корректное исправление: открываю
# Предсказание: открытию
#
# Реальное слово: высыпвние	\	Корректное исправление: высыпание
# Предсказание: высыпания
#
# Реальное слово: забавен	\	Корректное исправление: забавен
# Предсказание: занавес
#
# Реальное слово: хламину	\	Корректное исправление: хламину
# Предсказание: ламину
#
# Реальное слово: пяный	\	Корректное исправление: пьяный
# Предсказание: пятый
#
# Реальное слово: фотка	\	Корректное исправление: фотка
# Предсказание: фока
#
# Реальное слово: подоплеке	\	Корректное исправление: подоплеке
# Предсказание: подоплёка
#
# Реальное слово: каком-никаком	\	Корректное исправление: каком-никаком
# Предсказание: какой-никакой
#
# Реальное слово: напряге	\	Корректное исправление: напряге
# Предсказание: напряги
#
# Реальное слово: каталась	\	Корректное исправление: каталась
# Предсказание: казалась
#
# Реальное слово: собстно	\	Корректное исправление: собственно
# Предсказание: собрано
#
# Реальное слово: рясах	\	Корректное исправление: рясах
# Предсказание: рядах
#
# Реальное слово: огроменных	\	Корректное исправление: огроменных
# Предсказание: опрошенных
#
# Реальное слово: неососознанно	\	Корректное исправление: неосознанно
# Предсказание: неосознанное
#
# Реальное слово: сохраю	\	Корректное исправление: сохраню
# Предсказание: собрал
#
# Реальное слово: сыро	\	Корректное исправление: сыро
# Предсказание: сыр
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: ат	\	Корректное исправление: ад
# Предсказание: ат
#
# Реальное слово: никада	\	Корректное исправление: никогда
# Предсказание: никуда
#
# Реальное слово: угадаете	\	Корректное исправление: угадаете
# Предсказание: угасает
#
# Реальное слово: пожже	\	Корректное исправление: позже
# Предсказание: пожже
#
# Реальное слово: материей	\	Корректное исправление: материей
# Предсказание: матерей
#
# Реальное слово: прокорм	\	Корректное исправление: прокорм
# Предсказание: сроком
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: джойстер	\	Корректное исправление: джойстер
# Предсказание: джойстик
#
# Реальное слово: молчу	\	Корректное исправление: молчу
# Предсказание: мочу
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: самыи	\	Корректное исправление: самый
# Предсказание: самым
#
# Реальное слово: гадости	\	Корректное исправление: гадости
# Предсказание: радости
#
# Реальное слово: но	\	Корректное исправление: на
# Предсказание: но
#
# Реальное слово: обидели	\	Корректное исправление: обидели
# Предсказание: обители
#
# Реальное слово: рекоммендация	\	Корректное исправление: рекомендации
# Предсказание: рекомендация
#
# Реальное слово: напректировали	\	Корректное исправление: напроектировали
# Предсказание: проектировали
#
# Реальное слово: раскину	\	Корректное исправление: раскину
# Предсказание: раскина
#
# Реальное слово: сплю	\	Корректное исправление: сплю
# Предсказание: салю
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: снежинка	\	Корректное исправление: снежинка
# Предсказание: снежинки
#
# Реальное слово: застрелиться	\	Корректное исправление: застрелиться
# Предсказание: застрелился
#
# Реальное слово: расплющиваются	\	Корректное исправление: расплющиваются
# Предсказание: расплачиваются
#
# Реальное слово: афальтоукладчик	\	Корректное исправление: асфальтоукладчик
# Предсказание: афальтоукладчик
#
# Реальное слово: проясненным	\	Корректное исправление: проясненным
# Предсказание: проявленным
#
# Реальное слово: кчакчество	\	Корректное исправление: качество
# Предсказание: качеством
#
# Реальное слово: зажатия	\	Корректное исправление: зажатия
# Предсказание: зачатия
#
# Реальное слово: пупковой	\	Корректное исправление: пупковой
# Предсказание: пусковой
#
# Реальное слово: бегущая	\	Корректное исправление: бегущая
# Предсказание: берущая
#
# Реальное слово: унываю	\	Корректное исправление: унываю
# Предсказание: унывать
#
# Реальное слово: прикодьные	\	Корректное исправление: прикольные
# Предсказание: природные
#
# Реальное слово: собстно	\	Корректное исправление: собственно
# Предсказание: собрано
#
# Реальное слово: пприкольные	\	Корректное исправление: прикольные
# Предсказание: привольные
#
# Реальное слово: начьните	\	Корректное исправление: начните
# Предсказание: значение
#
# Реальное слово: онвыгребает	\	Корректное исправление: он
# Предсказание: онвыгребает
#
# Реальное слово: ее	\	Корректное исправление: выгребает
# Предсказание: ее
#
# Реальное слово: из	\	Корректное исправление: ее
# Предсказание: из
#
# Реальное слово: под	\	Корректное исправление: из-под
# Предсказание: под
#
# Реальное слово: небыло	\	Корректное исправление: не
# Предсказание: немало
#
# Реальное слово: никогда	\	Корректное исправление: было
# Предсказание: никогда
#
# Реальное слово: любви	\	Корректное исправление: никогда
# Предсказание: любви
#
# Реальное слово: то	\	Корректное исправление: любви-то
# Предсказание: то
#
# Реальное слово: деловито	\	Корректное исправление: деловито
# Предсказание: делового
#
# Реальное слово: дружился	\	Корректное исправление: дружился
# Предсказание: сдружился
#
# Реальное слово: начальнице	\	Корректное исправление: начальнице
# Предсказание: начальнике
#
# Реальное слово: заити	\	Корректное исправление: зайти
# Предсказание: гаити
#
# Реальное слово: вконтакт	\	Корректное исправление: вконтакт
# Предсказание: контакт
#
# Реальное слово: ненавидшь	\	Корректное исправление: ненавидишь
# Предсказание: ненависть
#
# Реальное слово: мыслящаю	\	Корректное исправление: мыслящая
# Предсказание: мыслящей
#
# Реальное слово: убрть	\	Корректное исправление: убрать
# Предсказание: убить
#
# Реальное слово: мишуру	\	Корректное исправление: мишуру
# Предсказание: мицуру
#
# Реальное слово: процедудура	\	Корректное исправление: процедура
# Предсказание: процедурам
#
# Реальное слово: гордуму	\	Корректное исправление: гордуму
# Предсказание: гордому
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: свредничала	\	Корректное исправление: свредничала
# Предсказание: посредничал
#
# Реальное слово: продавщицу	\	Корректное исправление: продавщицу
# Предсказание: продавщиц
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: бесит	\	Корректное исправление: бесит
# Предсказание: бежит
#
# Реальное слово: увольняться	\	Корректное исправление: увольняться
# Предсказание: увольняется
#
# Реальное слово: сером	\	Корректное исправление: серой
# Предсказание: сером
#
# Реальное слово: рисунко	\	Корректное исправление: рисунком
# Предсказание: рисунки
#
# Реальное слово: упоением	\	Корректное исправление: упоением
# Предсказание: умением
#
# Реальное слово: сухинова	\	Корректное исправление: сухинова
# Предсказание: суханова
#
# Реальное слово: продолжения	\	Корректное исправление: продолжение
# Предсказание: продолжения
#
# Реальное слово: бякость	\	Корректное исправление: бякость
# Предсказание: мякость
#
# Реальное слово: взываю	\	Корректное исправление: взываю
# Предсказание: взывал
#
# Реальное слово: спичечного	\	Корректное исправление: спичечного
# Предсказание: почечного
#
# Реальное слово: тасовоать	\	Корректное исправление: тасовать
# Предсказание: фасовать
#
# Реальное слово: опаздываю	\	Корректное исправление: опаздываю
# Предсказание: опаздывал
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: страааашно	\	Корректное исправление: страшно
# Предсказание: страааашно
#
# Реальное слово: обогреватель	\	Корректное исправление: обогреватель
# Предсказание: обозреватель
#
# Реальное слово: окромя	\	Корректное исправление: окромя
# Предсказание: кроме
#
# Реальное слово: канешна	\	Корректное исправление: конечно
# Предсказание: кантона
#
# Реальное слово: превратит	\	Корректное исправление: превратит
# Предсказание: превратить
#
# Реальное слово: фарш	\	Корректное исправление: фарш
# Предсказание: марш
#
# Реальное слово: празнег	\	Корректное исправление: праздник
# Предсказание: разбег
#
# Реальное слово: жуть	\	Корректное исправление: жуть
# Предсказание: путь
#
# Реальное слово: встретицца	\	Корректное исправление: встретиться
# Предсказание: встретила
#
# Реальное слово: нажусь	\	Корректное исправление: нахожусь
# Предсказание: нажать
#
# Реальное слово: непонятном	\	Корректное исправление: непонятном
# Предсказание: непонятно
#
# Реальное слово: паршивое	\	Корректное исправление: паршивое
# Предсказание: паровое
#
# Реальное слово: закипания	\	Корректное исправление: закипания
# Предсказание: залипания
#
# Реальное слово: сайлау	\	Корректное исправление: сайлау
# Предсказание: жайлау
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: брыкаться	\	Корректное исправление: брыкаться
# Предсказание: бросаться
#
# Реальное слово: визжать	\	Корректное исправление: визжать
# Предсказание: вызвать
#
# Реальное слово: дооолго	\	Корректное исправление: долго
# Предсказание: дорого
#
# Реальное слово: садится	\	Корректное исправление: садиться
# Предсказание: садится
#
# Реальное слово: залпы	\	Корректное исправление: залпы
# Предсказание: залы
#
# Реальное слово: беглянок	\	Корректное исправление: беглянок
# Предсказание: белянок
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: календарику	\	Корректное исправление: календарику
# Предсказание: календариков
#
# Реальное слово: зачеркиваю	\	Корректное исправление: зачеркиваю
# Предсказание: задерживаю
#
# Реальное слово: крестики	\	Корректное исправление: крестики
# Предсказание: крестик
#
# Реальное слово: чудябриков	\	Корректное исправление: чудябриков
# Предсказание: чубариков
#
# Реальное слово: полюбому	\	Корректное исправление: по-любому
# Предсказание: полному
#
# Реальное слово: ослуживание	\	Корректное исправление: ослуживание
# Предсказание: обслуживание
#
# Реальное слово: ищите	\	Корректное исправление: ищете
# Предсказание: ищите
#
# Реальное слово: какова	\	Корректное исправление: какого
# Предсказание: какова
#
# Реальное слово: раена	\	Корректное исправление: района
# Предсказание: равна
#
# Реальное слово: объясни	\	Корректное исправление: объясни
# Предсказание: объяснил
#
# Реальное слово: сначало	\	Корректное исправление: сначала
# Предсказание: начало
#
# Реальное слово: прикупить	\	Корректное исправление: прикупить
# Предсказание: приступить
#
# Реальное слово: продул	\	Корректное исправление: продул
# Предсказание: продал
#
# Реальное слово: угошали	\	Корректное исправление: угощали
# Предсказание: угрожали
#
# Реальное слово: подделаная	\	Корректное исправление: подделанная
# Предсказание: поддельная
#
# Реальное слово: неаутентична	\	Корректное исправление: неаутентична
# Предсказание: аутентичная
#
# Реальное слово: подрбный	\	Корректное исправление: подробный
# Предсказание: подобный
#
# Реальное слово: обдумывю	\	Корректное исправление: обдумываю
# Предсказание: обдумывал
#
# Реальное слово: постинги	\	Корректное исправление: постинги
# Предсказание: постигли
#
# Реальное слово: вкусному	\	Корректное исправление: вкусному
# Предсказание: вкусное
#
# Реальное слово: познакомицца	\	Корректное исправление: познакомиться
# Предсказание: познакомила
#
# Реальное слово: большое	\	Корректное исправление: большой
# Предсказание: большое
#
# Реальное слово: шульга	\	Корректное исправление: шульга
# Предсказание: шульца
#
# Реальное слово: зимариным	\	Корректное исправление: зимариным
# Предсказание: зимарины
#
# Реальное слово: незнаю	\	Корректное исправление: не
# Предсказание: ненад
#
# Реальное слово: ходить	\	Корректное исправление: знаю
# Предсказание: ходить
#
# Реальное слово: на	\	Корректное исправление: ходить
# Предсказание: на
#
# Реальное слово: море	\	Корректное исправление: на
# Предсказание: море
#
# Реальное слово: делать	\	Корректное исправление: море
# Предсказание: делать
#
# Реальное слово: ремонт	\	Корректное исправление: делать
# Предсказание: ремонт
#
# Реальное слово: кого	\	Корректное исправление: ремонт
# Предсказание: кого
#
# Реальное слово: нибудь	\	Корректное исправление: кого-нибудь
# Предсказание: никуда
#
# Реальное слово: насмотрелся	\	Корректное исправление: насмотрелся
# Предсказание: осмотрелся
#
# Реальное слово: лосяра	\	Корректное исправление: лосяра
# Предсказание: осера
#
# Реальное слово: сроду	\	Корректное исправление: сроду
# Предсказание: роду
#
# Реальное слово: ощастливленный	\	Корректное исправление: осчастливленный
# Предсказание: ощастливленный
#
# Реальное слово: выхожу	\	Корректное исправление: выхожу
# Предсказание: выходу
#
# Реальное слово: решаем	\	Корректное исправление: решаем
# Предсказание: решает
#
# Реальное слово: левонтием	\	Корректное исправление: левонтием
# Предсказание: леонтием
#
# Реальное слово: оным	\	Корректное исправление: оным
# Предсказание: иным
#
# Реальное слово: коньяком	\	Корректное исправление: коньяком
# Предсказание: коньком
#
# Реальное слово: колой	\	Корректное исправление: колой
# Предсказание: школой
#
# Реальное слово: спрашиваю	\	Корректное исправление: спрашиваю
# Предсказание: спрашивал
#
# Реальное слово: поведйте	\	Корректное исправление: поведайте
# Предсказание: поведать
#
# Реальное слово: плиз	\	Корректное исправление: плиз
# Предсказание: близ
#
# Реальное слово: тока	\	Корректное исправление: только
# Предсказание: тока
#
# Реальное слово: сдай	\	Корректное исправление: сдай
# Предсказание: сдан
#
# Реальное слово: сушит	\	Корректное исправление: сушит
# Предсказание: суши
#
# Реальное слово: притянулись	\	Корректное исправление: притянулись
# Предсказание: протянулись
#
# Реальное слово: нагибается	\	Корректное исправление: нагибается
# Предсказание: загибается
#
# Реальное слово: читаемсоть	\	Корректное исправление: читаемость
# Предсказание: читаемости
#
# Реальное слово: потмоу	\	Корректное исправление: потому
# Предсказание: потом
#
# Реальное слово: присоединаюсь	\	Корректное исправление: присоединяюсь
# Предсказание: присоединяясь
#
# Реальное слово: негодованию	\	Корректное исправление: негодованию
# Предсказание: негодование
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: отколотых	\	Корректное исправление: отколотых
# Предсказание: отколоток
#
# Реальное слово: вчерашним	\	Корректное исправление: вчерашним
# Предсказание: вчерашний
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: лосьончека	\	Корректное исправление: лосьончика
# Предсказание: лосьончека
#
# Реальное слово: пользовать	\	Корректное исправление: пользовать
# Предсказание: использовать
#
# Реальное слово: скучала	\	Корректное исправление: скучала
# Предсказание: скучали
#
# Реальное слово: девкам	\	Корректное исправление: девкам
# Предсказание: девам
#
# Реальное слово: двухполюсная	\	Корректное исправление: двухполюсная
# Предсказание: двухполосная
#
# Реальное слово: приезла	\	Корректное исправление: привезла
# Предсказание: приезда
#
# Реальное слово: чудище	\	Корректное исправление: чудище
# Предсказание: будище
#
# Реальное слово: просвестевшая	\	Корректное исправление: просвистевшая
# Предсказание: просвестевшая
#
# Реальное слово: оберутся	\	Корректное исправление: обернуться
# Предсказание: берутся
#
# Реальное слово: монсерат	\	Корректное исправление: монсерат
# Предсказание: монстра
#
# Реальное слово: матерю	\	Корректное исправление: матерю
# Предсказание: матери
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: лешил	\	Корректное исправление: лишил
# Предсказание: решил
#
# Реальное слово: касаемо	\	Корректное исправление: касаемо
# Предсказание: даваемо
#
# Реальное слово: эрендзи	\	Корректное исправление: эрендзи
# Предсказание: эфенди
#
# Реальное слово: норнштейн	\	Корректное исправление: норнштейн
# Предсказание: норштейн
#
# Реальное слово: гордится	\	Корректное исправление: гордиться
# Предсказание: гордится
#
# Реальное слово: посорилась	\	Корректное исправление: поссорилась
# Предсказание: покорилась
#
# Реальное слово: подружусь	\	Корректное исправление: подружусь
# Предсказание: подружить
#
# Реальное слово: какимнить	\	Корректное исправление: каким-нибудь
# Предсказание: какимнить
#
# Реальное слово: лж	\	Корректное исправление: лж
# Предсказание: л
#
# Реальное слово: выложу	\	Корректное исправление: выложу
# Предсказание: вылову
#
# Реальное слово: пластырь	\	Корректное исправление: пластырь
# Предсказание: пастырь
#
# Реальное слово: никоретте	\	Корректное исправление: никоретте
# Предсказание: николетт
#
# Реальное слово: дае	\	Корректное исправление: даже
# Предсказание: дае
#
# Реальное слово: нотную	\	Корректное исправление: нотную
# Предсказание: ночную
#
# Реальное слово: молчу	\	Корректное исправление: молчу
# Предсказание: мочу
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: паути	\	Корректное исправление: паутину
# Предсказание: пути
#
# Реальное слово: неридуманная	\	Корректное исправление: непридуманная
# Предсказание: неридуманная
#
# Реальное слово: перессказываю	\	Корректное исправление: пересказываю
# Предсказание: пересказывая
#
# Реальное слово: постараюсь	\	Корректное исправление: постараюсь
# Предсказание: постарался
#
# Реальное слово: подргрузился	\	Корректное исправление: подгрузился
# Предсказание: подргрузился
#
# Реальное слово: наберала	\	Корректное исправление: набирала
# Предсказание: набрала
#
# Реальное слово: девченки	\	Корректное исправление: девчонки
# Предсказание: шевченко
#
# Реальное слово: завижжали	\	Корректное исправление: завизжали
# Предсказание: завижжали
#
# Реальное слово: аккордах	\	Корректное исправление: аккордах
# Предсказание: аккорда
#
# Реальное слово: бэндом	\	Корректное исправление: бэндом
# Предсказание: бондом
#
# Реальное слово: невозмозможно	\	Корректное исправление: невозможно
# Предсказание: невозмозможно
#
# Реальное слово: привожу	\	Корректное исправление: привожу
# Предсказание: приводу
#
# Реальное слово: рассчет	\	Корректное исправление: расчет
# Предсказание: рассвет
#
# Реальное слово: пристегиваться	\	Корректное исправление: пристегиваться
# Предсказание: притягиваться
#
# Реальное слово: будеш	\	Корректное исправление: будешь
# Предсказание: будет
#
# Реальное слово: преинтерснейшее	\	Корректное исправление: преинтереснейшее
# Предсказание: преинтерснейшее
#
# Реальное слово: улыбнуло	\	Корректное исправление: улыбнуло
# Предсказание: хлынуло
#
# Реальное слово: дооолго	\	Корректное исправление: долго
# Предсказание: дорого
#
# Реальное слово: тянула	\	Корректное исправление: тянула
# Предсказание: тянул
#
# Реальное слово: батон	\	Корректное исправление: батон
# Предсказание: барон
#
# Реальное слово: пятиэтажки	\	Корректное исправление: пятиэтажки
# Предсказание: пятиэтажке
#
# Реальное слово: мя	\	Корректное исправление: я
# Предсказание: мя
#
# Реальное слово: привыкла	\	Корректное исправление: привыкла
# Предсказание: привыкли
#
# Реальное слово: именины	\	Корректное исправление: именины
# Предсказание: имениты
#
# Реальное слово: преодолеванием	\	Корректное исправление: преодолеванием
# Предсказание: переодеванием
#
# Реальное слово: протискивались	\	Корректное исправление: протискивались
# Предсказание: оттискивались
#
# Реальное слово: ползли	\	Корректное исправление: ползли
# Предсказание: полли
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: наплавалась	\	Корректное исправление: наплавалась
# Предсказание: направилась
#
# Реальное слово: што	\	Корректное исправление: что
# Предсказание: што
#
# Реальное слово: бомжи	\	Корректное исправление: бомжи
# Предсказание: божи
#
# Реальное слово: дерущиеся	\	Корректное исправление: дерущиеся
# Предсказание: дерущийся
#
# Реальное слово: бомжи	\	Корректное исправление: бомжи
# Предсказание: божи
#
# Реальное слово: осталалось	\	Корректное исправление: осталось
# Предсказание: оставалось
#
# Реальное слово: видюха	\	Корректное исправление: видюха
# Предсказание: видах
#
# Реальное слово: стратусы	\	Корректное исправление: статусы
# Предсказание: стратус
#
# Реальное слово: однокурссница	\	Корректное исправление: однокурсница
# Предсказание: одноклассница
#
# Реальное слово: аське	\	Корректное исправление: аське
# Предсказание: аске
#
# Реальное слово: лабораторках	\	Корректное исправление: лабораторках
# Предсказание: лабораторных
#
# Реальное слово: джинсовые	\	Корректное исправление: джинсовые
# Предсказание: джинсовую
#
# Реальное слово: свалились	\	Корректное исправление: свалились
# Предсказание: свалилась
#
# Реальное слово: треснуть	\	Корректное исправление: треснуть
# Предсказание: треснуто
#
# Реальное слово: сначало	\	Корректное исправление: сначала
# Предсказание: начало
#
# Реальное слово: тарусу	\	Корректное исправление: тарусу
# Предсказание: тарасу
#
# Реальное слово: ессно	\	Корректное исправление: естественно
# Предсказание: ясно
#
# Реальное слово: созерцала	\	Корректное исправление: созерцала
# Предсказание: созерцал
#
# Реальное слово: попробую	\	Корректное исправление: попробую
# Предсказание: попробуй
#
# Реальное слово: измученная	\	Корректное исправление: измученная
# Предсказание: изученная
#
# Реальное слово: ознобом	\	Корректное исправление: ознобом
# Предсказание: особом
#
# Реальное слово: зарылась	\	Корректное исправление: зарылась
# Предсказание: закрылась
#
# Реальное слово: неделимое	\	Корректное исправление: неделимое
# Предсказание: неделимой
#
# Реальное слово: маршрутки	\	Корректное исправление: маршрутки
# Предсказание: маршрутка
#
# Реальное слово: битком	\	Корректное исправление: битком
# Предсказание: ситком
#
# Реальное слово: позаввчера	\	Корректное исправление: позавчера
# Предсказание: позаввчера
#
# Реальное слово: горбатую	\	Корректное исправление: горбатую
# Предсказание: горбатки
#
# Реальное слово: всплыло	\	Корректное исправление: всплыло
# Предсказание: всплыл
#
# Реальное слово: рученки	\	Корректное исправление: ручонки
# Предсказание: ученики
#
# Реальное слово: кнопачки	\	Корректное исправление: кнопочки
# Предсказание: копанки
#
# Реальное слово: профайле	\	Корректное исправление: профайле
# Предсказание: профиле
#
# Реальное слово: накатать	\	Корректное исправление: накатать
# Предсказание: наказать
#
# Реальное слово: прикладывам	\	Корректное исправление: прикладываем
# Предсказание: прикладывая
#
# Реальное слово: лобику	\	Корректное исправление: лобику
# Предсказание: логику
#
# Реальное слово: извлеченное	\	Корректное исправление: извлеченное
# Предсказание: извлеченные
#
# Реальное слово: осматриваем	\	Корректное исправление: осматриваем
# Предсказание: осматривает
#
# Реальное слово: следеите	\	Корректное исправление: следите
# Предсказание: следить
#
# Реальное слово: лежаки	\	Корректное исправление: лежаки
# Предсказание: лежали
#
# Реальное слово: денги	\	Корректное исправление: деньги
# Предсказание: денги
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: 3хчасовой	\	Корректное исправление: трехчасовой
# Предсказание: 3-часовой
#
# Реальное слово: кодексам	\	Корректное исправление: кодексам
# Предсказание: кодекса
#
# Реальное слово: заверив	\	Корректное исправление: заверив
# Предсказание: завершив
#
# Реальное слово: заверителей	\	Корректное исправление: заверителей
# Предсказание: заменителей
#
# Реальное слово: проставив	\	Корректное исправление: проставив
# Предсказание: поставив
#
# Реальное слово: поздравляю	\	Корректное исправление: поздравляю
# Предсказание: поздравляют
#
# Реальное слово: обрадовались	\	Корректное исправление: обрадовались
# Предсказание: образовались
#
# Реальное слово: доброжелательный	\	Корректное исправление: доброжелательный
# Предсказание: доброжелательным
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: накачанными	\	Корректное исправление: накачанными
# Предсказание: наказанными
#
# Реальное слово: прогматично	\	Корректное исправление: прагматично
# Предсказание: романтично
#
# Реальное слово: подумайте	\	Корректное исправление: подумайте
# Предсказание: подумать
#
# Реальное слово: общаються	\	Корректное исправление: общаются
# Предсказание: общаться
#
# Реальное слово: вобщем	\	Корректное исправление: в
# Предсказание: общем
#
# Реальное слово: сниццо	\	Корректное исправление: общем
# Предсказание: ницце
#
# Реальное слово: мне	\	Корректное исправление: снится
# Предсказание: мне
#
# Реальное слово: что	\	Корректное исправление: мне
# Предсказание: что
#
# Реальное слово: я	\	Корректное исправление: что
# Предсказание: я
#
# Реальное слово: нашел	\	Корректное исправление: я
# Предсказание: нашел
#
# Реальное слово: таки	\	Корректное исправление: нашел-таки
# Предсказание: таки
#
# Реальное слово: сволачи	\	Корректное исправление: сволочи
# Предсказание: валачи
#
# Реальное слово: подхожу	\	Корректное исправление: подхожу
# Предсказание: подходу
#
# Реальное слово: скребут	\	Корректное исправление: скребут
# Предсказание: скребки
#
# Реальное слово: апять	\	Корректное исправление: опять
# Предсказание: пять
#
# Реальное слово: ана	\	Корректное исправление: она
# Предсказание: ана
#
# Реальное слово: наливаю	\	Корректное исправление: наливаю
# Предсказание: наливают
#
# Реальное слово: кулере	\	Корректное исправление: кулере
# Предсказание: кулер
#
# Реальное слово: смешиваю	\	Корректное исправление: смешиваю
# Предсказание: смешивают
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: холооодная	\	Корректное исправление: холодная
# Предсказание: холооодная
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: доолго-дооолго-доооолго	\	Корректное исправление: долго-долго-долго
# Предсказание: доолго-дооолго-доооолго
#
# Реальное слово: юстировал	\	Корректное исправление: юстировал
# Предсказание: цитировал
#
# Реальное слово: элитному	\	Корректное исправление: элитному
# Предсказание: элитном
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: обструктивной	\	Корректное исправление: обструктивной
# Предсказание: конструктивной
#
# Реальное слово: ессно	\	Корректное исправление: естественно
# Предсказание: ясно
#
# Реальное слово: эксурсоводы	\	Корректное исправление: экскурсоводы
# Предсказание: экскурсовод
#
# Реальное слово: значет	\	Корректное исправление: значит
# Предсказание: знает
#
# Реальное слово: кено	\	Корректное исправление: кино
# Предсказание: кено
#
# Реальное слово: кедал	\	Корректное исправление: кидал
# Предсказание: дедал
#
# Реальное слово: кедалы	\	Корректное исправление: кидалы
# Предсказание: медали
#
# Реальное слово: подскажыте	\	Корректное исправление: подскажите
# Предсказание: подскажыте
#
# Реальное слово: зазырить	\	Корректное исправление: зазырить
# Предсказание: заверить
#
# Реальное слово: кровищщи	\	Корректное исправление: кровищи
# Предсказание: сокровищ
#
# Реальное слово: покапаться	\	Корректное исправление: покопаться
# Предсказание: показаться
#
# Реальное слово: выхи	\	Корректное исправление: выхи
# Предсказание: всхи
#
# Реальное слово: люда	\	Корректное исправление: люда
# Предсказание: люди
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: рекокомендую	\	Корректное исправление: рекомендую
# Предсказание: рекомендуют
#
# Реальное слово: проморзгло	\	Корректное исправление: промозгло
# Предсказание: проморзгло
#
# Реальное слово: муторно	\	Корректное исправление: муторно
# Предсказание: упорно
#
# Реальное слово: вообщем	\	Корректное исправление: в
# Предсказание: вообще
#
# Реальное слово: то	\	Корректное исправление: общем-то
# Предсказание: то
#
# Реальное слово: пекарской	\	Корректное исправление: пекарской
# Предсказание: пекарский
#
# Реальное слово: натертый	\	Корректное исправление: натертый
# Предсказание: натёртые
#
# Реальное слово: цедру	\	Корректное исправление: цедру
# Предсказание: педру
#
# Реальное слово: сушить	\	Корректное исправление: сушить
# Предсказание: судить
#
# Реальное слово: финдиректор	\	Корректное исправление: финдиректор
# Предсказание: гендиректор
#
# Реальное слово: напьешся	\	Корректное исправление: напьешься
# Предсказание: напиться
#
# Реальное слово: соратникам	\	Корректное исправление: соратникам
# Предсказание: соратника
#
# Реальное слово: дирижаблями	\	Корректное исправление: дирижаблями
# Предсказание: дирижаблях
#
# Реальное слово: нсущного	\	Корректное исправление: насущного
# Предсказание: научного
#
# Реальное слово: теоретизированое	\	Корректное исправление: теоретизированное
# Предсказание: теоретизирования
#
# Реальное слово: что	\	Корректное исправление: чтобы
# Предсказание: что
#
# Реальное слово: бы	\	Корректное исправление: больно
# Предсказание: бы
#
# Реальное слово: больно	\	Корректное исправление: не
# Предсказание: больно
#
# Реальное слово: небыло	\	Корректное исправление: было
# Предсказание: немало
#
# Реальное слово: мочь	\	Корректное исправление: мочь
# Предсказание: дочь
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: одно	\	Корректное исправление: одна
# Предсказание: одно
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: аццки	\	Корректное исправление: адски
# Предсказание: атаки
#
# Реальное слово: мааааммоооочкииии	\	Корректное исправление: мамочки
# Предсказание: мааааммоооочкииии
#
# Реальное слово: госов	\	Корректное исправление: госов
# Предсказание: годов
#
# Реальное слово: осложнен	\	Корректное исправление: осложнен
# Предсказание: осложнён
#
# Реальное слово: програмка	\	Корректное исправление: программка
# Предсказание: программа
#
# Реальное слово: преславутая	\	Корректное исправление: пресловутая
# Предсказание: преславутая
#
# Реальное слово: подкованная	\	Корректное исправление: подкованная
# Предсказание: подорванная
#
# Реальное слово: вырозился	\	Корректное исправление: выразился
# Предсказание: вывозился
#
# Реальное слово: напоменило	\	Корректное исправление: напомнило
# Предсказание: напоминало
#
# Реальное слово: стааарый	\	Корректное исправление: старый
# Предсказание: ста́рый
#
# Реальное слово: прийдя	\	Корректное исправление: придя
# Предсказание: пройдя
#
# Реальное слово: иракез	\	Корректное исправление: ирокез
# Предсказание: ираке
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: обьехав	\	Корректное исправление: объехав
# Предсказание: обещав
#
# Реальное слово: вьехал	\	Корректное исправление: въехал
# Предсказание: выехал
#
# Реальное слово: сандово	\	Корректное исправление: сандово
# Предсказание: заново
#
# Реальное слово: ля-ля	\	Корректное исправление: ля-ля
# Предсказание: ляля
#
# Реальное слово: ни	\	Корректное исправление: не
# Предсказание: ни
#
# Реальное слово: натянуто	\	Корректное исправление: натянуто
# Предсказание: натянуть
#
# Реальное слово: дарвиновского	\	Корректное исправление: дарвиновского
# Предсказание: сарвановского
#
# Реальное слово: какбы	\	Корректное исправление: как
# Предсказание: каабы
#
# Реальное слово: из	\	Корректное исправление: бы
# Предсказание: из
#
# Реальное слово: под	\	Корректное исправление: из-под
# Предсказание: под
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: новозаветняя	\	Корректное исправление: новозаветная
# Предсказание: новозаветной
#
# Реальное слово: рулит	\	Корректное исправление: рулит
# Предсказание: рули
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: обычныэ	\	Корректное исправление: обычные
# Предсказание: обычных
#
# Реальное слово: негодныэ	\	Корректное исправление: негодные
# Предсказание: негодным
#
# Реальное слово: любю	\	Корректное исправление: люблю
# Предсказание: любую
#
# Реальное слово: кефир	\	Корректное исправление: кефир
# Предсказание: зефир
#
# Реальное слово: глинтвейном	\	Корректное исправление: глинтвейном
# Предсказание: глинтвейна
#
# Реальное слово: неприглядно	\	Корректное исправление: неприглядно
# Предсказание: неприглядна
#
# Реальное слово: непредставительно	\	Корректное исправление: непредставительно
# Предсказание: непредставительным
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: бабежку	\	Корректное исправление: бабешку
# Предсказание: бабенко
#
# Реальное слово: промолчу	\	Корректное исправление: промолчу
# Предсказание: промоину
#
# Реальное слово: трепа	\	Корректное исправление: трепа
# Предсказание: трека
#
# Реальное слово: нарыть	\	Корректное исправление: нарыть
# Предсказание: начать
#
# Реальное слово: жемчуженки	\	Корректное исправление: жемчужинки
# Предсказание: жемчужниц
#
# Реальное слово: постраее	\	Корректное исправление: постарее
# Предсказание: построен
#
# Реальное слово: дедуля	\	Корректное исправление: дедуля
# Предсказание: модуля
#
# Реальное слово: прийдя	\	Корректное исправление: придя
# Предсказание: пройдя
#
# Реальное слово: сачков	\	Корректное исправление: сачков
# Предсказание: саков
#
# Реальное слово: острое	\	Корректное исправление: острове
# Предсказание: острое
#
# Реальное слово: превратититься	\	Корректное исправление: превратиться
# Предсказание: превратититься
#
# Реальное слово: кляксу	\	Корректное исправление: кляксу
# Предсказание: классу
#
# Реальное слово: смяться	\	Корректное исправление: смяться
# Предсказание: сняться
#
# Реальное слово: разжижиться	\	Корректное исправление: разжижиться
# Предсказание: разжижаться
#
# Реальное слово: стечь	\	Корректное исправление: стечь
# Предсказание: степь
#
# Реальное слово: горестными	\	Корректное исправление: горестными
# Предсказание: окрестными
#
# Реальное слово: ссоримся	\	Корректное исправление: ссоримся
# Предсказание: ссорится
#
# Реальное слово: правоты	\	Корректное исправление: правоты
# Предсказание: правоте
#
# Реальное слово: фотки	\	Корректное исправление: фотки
# Предсказание: фоки
#
# Реальное слово: фоток	\	Корректное исправление: фоток
# Предсказание: поток
#
# Реальное слово: залил	\	Корректное исправление: залил
# Предсказание: забил
#
# Реальное слово: че	\	Корректное исправление: что
# Предсказание: че
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: утешюсь	\	Корректное исправление: утешаюсь
# Предсказание: утешить
#
# Реальное слово: ошпареных	\	Корректное исправление: ошпаренных
# Предсказание: спаренных
#
# Реальное слово: пыттаюсь	\	Корректное исправление: пытаюсь
# Предсказание: пытаясь
#
# Реальное слово: загоняю	\	Корректное исправление: загоняю
# Предсказание: загоняет
#
# Реальное слово: универа	\	Корректное исправление: универа
# Предсказание: уивера
#
# Реальное слово: отпразную	\	Корректное исправление: отпраздную
# Предсказание: отправную
#
# Реальное слово: отвечу	\	Корректное исправление: отвечу
# Предсказание: ответу
#
# Реальное слово: комменты	\	Корректное исправление: комменты
# Предсказание: коммуны
#
# Реальное слово: текилки	\	Корректное исправление: текилки
# Предсказание: кекилли
#
# Реальное слово: убеждены	\	Корректное исправление: убеждены
# Предсказание: убежден
#
# Реальное слово: скзала	\	Корректное исправление: сказала
# Предсказание: скала
#
# Реальное слово: советую	\	Корректное исправление: советую
# Предсказание: совету
#
# Реальное слово: пасиб	\	Корректное исправление: спасибо
# Предсказание: насиб
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: рванина	\	Корректное исправление: рванина
# Предсказание: ванина
#
# Реальное слово: сос	\	Корректное исправление: со
# Предсказание: сос
#
# Реальное слово: встречавщимися	\	Корректное исправление: встречавшимися
# Предсказание: встречающимися
#
# Реальное слово: обогреваемый	\	Корректное исправление: обогреваемый
# Предсказание: обогреваемые
#
# Реальное слово: солнушком	\	Корректное исправление: солнышком
# Предсказание: солнышко
#
# Реальное слово: чтоы	\	Корректное исправление: чтобы
# Предсказание: что
#
# Реальное слово: насчт	\	Корректное исправление: насчет
# Предсказание: насчёт
#
# Реальное слово: меняемся	\	Корректное исправление: меняемся
# Предсказание: меняется
#
# Реальное слово: пронизтельно	\	Корректное исправление: пронзительно
# Предсказание: проницательно
#
# Реальное слово: теперешний	\	Корректное исправление: теперешний
# Предсказание: теперешней
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: прописочкой	\	Корректное исправление: прописочкой
# Предсказание: прорисовкой
#
# Реальное слово: дошутилась	\	Корректное исправление: дошутилась
# Предсказание: докатилась
#
# Реальное слово: ждем	\	Корректное исправление: ждем
# Предсказание: ждет
#
# Реальное слово: напыщеные	\	Корректное исправление: напыщенные
# Предсказание: насыщенные
#
# Реальное слово: стискивают	\	Корректное исправление: стискивают
# Предсказание: отыскивают
#
# Реальное слово: прдолжаем	\	Корректное исправление: продолжаем
# Предсказание: продолжает
#
# Реальное слово: солцне	\	Корректное исправление: солнце
# Предсказание: долине
#
# Реальное слово: тока	\	Корректное исправление: только
# Предсказание: тока
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: пингу-понгу	\	Корректное исправление: пинг-понг
# Предсказание: пинг-понгом
#
# Реальное слово: разгребала	\	Корректное исправление: разгребала
# Предсказание: разрешала
#
# Реальное слово: творятся	\	Корректное исправление: творятся
# Предсказание: творится
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: сэкономили	\	Корректное исправление: сэкономили
# Предсказание: экономики
#
# Реальное слово: значет	\	Корректное исправление: значит
# Предсказание: знает
#
# Реальное слово: повозиться	\	Корректное исправление: повозиться
# Предсказание: проводиться
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: глюки	\	Корректное исправление: глюки
# Предсказание: люки
#
# Реальное слово: мещанский	\	Корректное исправление: мещанский
# Предсказание: мещанской
#
# Реальное слово: добавляю	\	Корректное исправление: добавляю
# Предсказание: добавляют
#
# Реальное слово: елку	\	Корректное исправление: елку
# Предсказание: ёлку
#
# Реальное слово: отдирла	\	Корректное исправление: отдирала
# Предсказание: отдела
#
# Реальное слово: бантики	\	Корректное исправление: бантики
# Предсказание: балтики
#
# Реальное слово: разворачивала	\	Корректное исправление: разворачивала
# Предсказание: разворачивал
#
# Реальное слово: извини	\	Корректное исправление: извини
# Предсказание: извинил
#
# Реальное слово: отыхаем	\	Корректное исправление: отдыхаем
# Предсказание: обычаем
#
# Реальное слово: садиков	\	Корректное исправление: садиков
# Предсказание: садков
#
# Реальное слово: прикольно	\	Корректное исправление: прикольно
# Предсказание: продольно
#
# Реальное слово: срочняком	\	Корректное исправление: срочняком
# Предсказание: сорняком
#
# Реальное слово: окей	\	Корректное исправление: окей
# Предсказание: осей
#
# Реальное слово: полюбому	\	Корректное исправление: по-любому
# Предсказание: полному
#
# Реальное слово: пересмотрю	\	Корректное исправление: пересмотрю
# Предсказание: пересмотр
#
# Реальное слово: огого	\	Корректное исправление: ого-го
# Предсказание: оного
#
# Реальное слово: захожу	\	Корректное исправление: захожу
# Предсказание: нахожу
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: погда	\	Корректное исправление: погода
# Предсказание: когда
#
# Реальное слово: установится	\	Корректное исправление: установится
# Предсказание: становится
#
# Реальное слово: доделаю	\	Корректное исправление: доделаю
# Предсказание: моделью
#
# Реальное слово: рекомундуемо	\	Корректное исправление: рекомендуемо
# Предсказание: рекомендуем
#
# Реальное слово: ровно	\	Корректное исправление: равно
# Предсказание: ровно
#
# Реальное слово: тахту	\	Корректное исправление: тахту
# Предсказание: тарту
#
# Реальное слово: стеллаж	\	Корректное исправление: стеллаж
# Предсказание: стелла
#
# Реальное слово: появляюсь	\	Корректное исправление: появляюсь
# Предсказание: появляясь
#
# Реальное слово: шкворчать	\	Корректное исправление: шкварчать
# Предсказание: шкворчать
#
# Реальное слово: остально	\	Корректное исправление: остальное
# Предсказание: остальной
#
# Реальное слово: парикмахерском	\	Корректное исправление: парикмахерском
# Предсказание: парикмахерской
#
# Реальное слово: огда	\	Корректное исправление: тогда
# Предсказание: когда
#
# Реальное слово: саправедливыми	\	Корректное исправление: справедливыми
# Предсказание: справедливым…
#
# Реальное слово: межведомственная	\	Корректное исправление: межведомственная
# Предсказание: межведомственной
#
# Реальное слово: слезяться	\	Корректное исправление: слезятся
# Предсказание: смеяться
#
# ...
# Предсказание: рейковыми
#
# Реальное слово: отуда	\	Корректное исправление: оттуда
# Предсказание: туда
#
# Реальное слово: байка	\	Корректное исправление: байка
# Предсказание: банка
#
# Реальное слово: ии	\	Корректное исправление: и
# Предсказание: ии
#
# Реальное слово: космополитеном	\	Корректное исправление: космополитеном
# Предсказание: космополитное
#
# Реальное слово: комнатки	\	Корректное исправление: комнатки
# Предсказание: комнатке
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: оказываецца	\	Корректное исправление: оказывается
# Предсказание: оказываемая
#
# Реальное слово: урбанист	\	Корректное исправление: урбанист
# Предсказание: органист
#
# Реальное слово: посочуствовали	\	Корректное исправление: посочувствовали
# Предсказание: способствовали
#
# Реальное слово: накинулись	\	Корректное исправление: накинулись
# Предсказание: начинались
#
# Реальное слово: курю	\	Корректное исправление: курю
# Предсказание: курс
#
# Реальное слово: порожке	\	Корректное исправление: порожке
# Предсказание: дорожке
#
# Реальное слово: милиционершу	\	Корректное исправление: милиционершу
# Предсказание: милиционеры
#
# Реальное слово: спрашиваю	\	Корректное исправление: спрашиваю
# Предсказание: спрашивал
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: поспшь	\	Корректное исправление: поспишь
# Предсказание: посеешь
#
# Реальное слово: непонятнх	\	Корректное исправление: непонятных
# Предсказание: непонятно
#
# Реальное слово: объяснала	\	Корректное исправление: объясняла
# Предсказание: объяснила
#
# Реальное слово: началнице	\	Корректное исправление: начальнице
# Предсказание: начальнике
#
# Реальное слово: играючи	\	Корректное исправление: играючи
# Предсказание: играли
#
# Реальное слово: вплетал	\	Корректное исправление: вплетал
# Предсказание: вылетал
#
# Реальное слово: покажутся	\	Корректное исправление: покажутся
# Предсказание: окажутся
#
# Реальное слово: куску	\	Корректное исправление: куску
# Предсказание: куско
#
# Реальное слово: бомжи	\	Корректное исправление: бомжи
# Предсказание: божи
#
# Реальное слово: банкроты	\	Корректное исправление: банкроты
# Предсказание: банкноты
#
# Реальное слово: юзаю	\	Корректное исправление: юзаю
# Предсказание: юза
#
# Реальное слово: юзать	\	Корректное исправление: юзать
# Предсказание: мать
#
# Реальное слово: стисняюсь	\	Корректное исправление: стесняюсь
# Предсказание: стесняясь
#
# Реальное слово: потмо	\	Корректное исправление: потом
# Предсказание: потро
#
# Реальное слово: стемнело	\	Корректное исправление: стемнело
# Предсказание: сембелло
#
# Реальное слово: дооолго	\	Корректное исправление: долго
# Предсказание: дорого
#
# Реальное слово: остаецца	\	Корректное исправление: остается
# Предсказание: останца
#
# Реальное слово: смириццо	\	Корректное исправление: смириться
# Предсказание: смириццо
#
# Реальное слово: бороццо	\	Корректное исправление: бороться
# Предсказание: борово
#
# Реальное слово: 4.60	\	Корректное исправление: 4.60
# Предсказание: 460
#
# Реальное слово: што	\	Корректное исправление: что
# Предсказание: што
#
# Реальное слово: полнеба	\	Корректное исправление: полнеба
# Предсказание: погреба
#
# Реальное слово: чорный	\	Корректное исправление: черный
# Предсказание: чёрный
#
# Реальное слово: мууультики	\	Корректное исправление: мультики
# Предсказание: мууультики
#
# Реальное слово: вернууулась	\	Корректное исправление: вернулась
# Предсказание: отвернулась
#
# Реальное слово: рааада	\	Корректное исправление: рaда
# Предсказание: рашада
#
# Реальное слово: распыленные	\	Корректное исправление: распыленные
# Предсказание: распиленных
#
# Реальное слово: возьмешь	\	Корректное исправление: возьмешь
# Предсказание: возьмет
#
# Реальное слово: напишут	\	Корректное исправление: напишут
# Предсказание: напишет
#
# Реальное слово: оббрызгивается	\	Корректное исправление: обрызгивается
# Предсказание: оббрызгивается
#
# Реальное слово: дешевыми	\	Корректное исправление: дешевыми
# Предсказание: дешевым
#
# Реальное слово: планируем	\	Корректное исправление: планируем
# Предсказание: планирует
#
# Реальное слово: развицо	\	Корректное исправление: развиться
# Предсказание: развито
#
# Реальное слово: молчат	\	Корректное исправление: молчат
# Предсказание: молча
#
# Реальное слово: проверяю	\	Корректное исправление: проверяю
# Предсказание: проверяя
#
# Реальное слово: трата	\	Корректное исправление: трата
# Предсказание: брата
#
# Реальное слово: абоpигенку	\	Корректное исправление: аборигенку
# Предсказание: абоpигенку
#
# Реальное слово: пpиезжей	\	Корректное исправление: приезжей
# Предсказание: проезжей
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: грабель	\	Корректное исправление: грабель
# Предсказание: габель
#
# Реальное слово: свершениям	\	Корректное исправление: свершениям
# Предсказание: свершения
#
# Реальное слово: blanca	\	Корректное исправление: blanca
# Предсказание: blanco
#
# Реальное слово: поеште	\	Корректное исправление: поешьте
# Предсказание: пеште
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: yкладываются	\	Корректное исправление: yкладываются
# Предсказание: складываются
#
# Реальное слово: тоpмозные	\	Корректное исправление: тоpмозные
# Предсказание: тормозные
#
# Реальное слово: котоpых	\	Корректное исправление: котоpых
# Предсказание: которых
#
# Реальное слово: артурчик	\	Корректное исправление: артурчик
# Предсказание: астурика
#
# Реальное слово: сестрицы	\	Корректное исправление: сестрицы
# Предсказание: лестницы
#
# Реальное слово: ни	\	Корректное исправление: не
# Предсказание: ни
#
# Реальное слово: пискнул	\	Корректное исправление: пискнул
# Предсказание: рискнул
#
# Реальное слово: мамином	\	Корректное исправление: мамином
# Предсказание: марином
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: потресающия	\	Корректное исправление: потрясающая
# Предсказание: потрясающие
#
# Реальное слово: преподовательница	\	Корректное исправление: преподавательница
# Предсказание: преподавательницы
#
# Реальное слово: кошшшшка	\	Корректное исправление: кошка
# Предсказание: кошшшшка
#
# Реальное слово: становлюсь	\	Корректное исправление: становлюсь
# Предсказание: остановлюсь
#
# Реальное слово: человеколюбивее	\	Корректное исправление: человеколюбивее
# Предсказание: человеколюбивый
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: применяю	\	Корректное исправление: применяю
# Предсказание: применяют
#
# Реальное слово: срываюсь	\	Корректное исправление: срываюсь
# Предсказание: срываясь
#
# Реальное слово: блеклым	\	Корректное исправление: блеклым
# Предсказание: блеклые
#
# Реальное слово: желаньем	\	Корректное исправление: желаньем
# Предсказание: желанием
#
# Реальное слово: контакти	\	Корректное исправление: контакте
# Предсказание: контакт
#
# Реальное слово: нукда	\	Корректное исправление: никуда
# Предсказание: нужда
#
# Реальное слово: поперлась	\	Корректное исправление: поперлась
# Предсказание: потерялась
#
# Реальное слово: ответтье	\	Корректное исправление: ответьте
# Предсказание: ответить
#
# Реальное слово: адресую	\	Корректное исправление: адресую
# Предсказание: адресу
#
# Реальное слово: барракуду	\	Корректное исправление: барракуду
# Предсказание: барракуд
#
# Реальное слово: созваниваемся	\	Корректное исправление: созваниваемся
# Предсказание: созванивается
#
# Реальное слово: выхватом	\	Корректное исправление: выхватом
# Предсказание: захватом
#
# Реальное слово: успевания	\	Корректное исправление: успевания
# Предсказание: отпевания
#
# Реальное слово: пробкам	\	Корректное исправление: пробкам
# Предсказание: пробка
#
# Реальное слово: минутам	\	Корректное исправление: минутам
# Предсказание: минута
#
# Реальное слово: какие	\	Корректное исправление: какие-то
# Предсказание: какие
#
# Реальное слово: то	\	Корректное исправление: плотники
# Предсказание: то
#
# Реальное слово: плотники	\	Корректное исправление: объясняя
# Предсказание: плотники
#
# Реальное слово: объясняя	\	Корректное исправление: экзаменатору
# Предсказание: объясняя
#
# Реальное слово: экзаменатору	\	Корректное исправление: что
# Предсказание: экзаменатору
#
# Реальное слово: что	\	Корректное исправление: связались
# Предсказание: что
#
# Реальное слово: связались	\	Корректное исправление: с
# Предсказание: связались
#
# Реальное слово: с	\	Корректное исправление: ней
# Предсказание: с
#
# Реальное слово: ней	\	Корректное исправление: через
# Предсказание: ней
#
# Реальное слово: через	\	Корректное исправление: емайл
# Предсказание: через
#
# Реальное слово: емайл	\	Корректное исправление: говорилось
# Предсказание: майкл
#
# Реальное слово: говорилось	\	Корректное исправление: о
# Предсказание: говорилось
#
# Реальное слово: о	\	Корректное исправление: заборе
# Предсказание: о
#
# Реальное слово: заборе	\	Корректное исправление: который
# Предсказание: заборе
#
# Реальное слово: который	\	Корректное исправление: не
# Предсказание: который
#
# Реальное слово: не	\	Корректное исправление: закрывается
# Предсказание: не
#
# Реальное слово: закрывается	\	Корректное исправление: затем
# Предсказание: закрывается
#
# Реальное слово: затем	\	Корректное исправление: зашла
# Предсказание: затем
#
# Реальное слово: зашла	\	Корректное исправление: не
# Предсказание: зашла
#
# Реальное слово: незнаю	\	Корректное исправление: знаю
# Предсказание: ненад
#
# Реальное слово: инете	\	Корректное исправление: инете
# Предсказание: инте
#
# Реальное слово: ничо	\	Корректное исправление: ничего
# Предсказание: нико
#
# Реальное слово: иво	\	Корректное исправление: его
# Предсказание: иво
#
# Реальное слово: шоколаде	\	Корректное исправление: шоколаде
# Предсказание: шоколада
#
# Реальное слово: связываем	\	Корректное исправление: связываем
# Предсказание: связывает
#
# Реальное слово: заразил	\	Корректное исправление: заразил
# Предсказание: выразил
#
# Реальное слово: компы	\	Корректное исправление: компы
# Предсказание: комы
#
# Реальное слово: запятых	\	Корректное исправление: запятых
# Предсказание: занятых
#
# Реальное слово: матерные	\	Корректное исправление: матерные
# Предсказание: матерые
#
# Реальное слово: позабодтесь	\	Корректное исправление: позаботьтесь
# Предсказание: позабодтесь
#
# Реальное слово: пофоторафировав	\	Корректное исправление: пофотографировав
# Предсказание: пофоторафировав
#
# Реальное слово: волнующие	\	Корректное исправление: волнующие
# Предсказание: волнующе
#
# Реальное слово: ессно	\	Корректное исправление: естественно
# Предсказание: ясно
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: постибалса	\	Корректное исправление: постебался
# Предсказание: постигала
#
# Реальное слово: едкому	\	Корректное исправление: едкому
# Предсказание: редкому
#
# Реальное слово: аромату	\	Корректное исправление: аромату
# Предсказание: аромат
#
# Реальное слово: штабель	\	Корректное исправление: штабель
# Предсказание: табель
#
# Реальное слово: сумбур	\	Корректное исправление: сумбур
# Предсказание: сумбура
#
# Реальное слово: эта	\	Корректное исправление: это
# Предсказание: эта
#
# Реальное слово: девченки	\	Корректное исправление: девчонки
# Предсказание: шевченко
#
# Реальное слово: заливаюсь	\	Корректное исправление: заливаюсь
# Предсказание: заливают
#
# Реальное слово: глянули	\	Корректное исправление: глянули
# Предсказание: грянули
#
# Реальное слово: напистаь	\	Корректное исправление: написать
# Предсказание: написал
#
# Реальное слово: стасу	\	Корректное исправление: стасу
# Предсказание: стану
#
# Реальное слово: ливня	\	Корректное исправление: ливня
# Предсказание: ливия
#
# Реальное слово: мыле	\	Корректное исправление: мыле
# Предсказание: мысе
#
# Реальное слово: пыраюсь	\	Корректное исправление: пытаюсь
# Предсказание: пытаясь
#
# Реальное слово: нарезает	\	Корректное исправление: нарезает
# Предсказание: нарезают
#
# Реальное слово: непридвиденные	\	Корректное исправление: непредвиденные
# Предсказание: непредвиденное
#
# Реальное слово: поздрваляю	\	Корректное исправление: поздравляю
# Предсказание: поздравляют
#
# Реальное слово: грю	\	Корректное исправление: говорю
# Предсказание: дрю
#
# Реальное слово: ничо	\	Корректное исправление: ничего
# Предсказание: нико
#
# Реальное слово: хотеццо	\	Корректное исправление: хотеться
# Предсказание: хотело
#
# Реальное слово: убиться	\	Корректное исправление: убиться
# Предсказание: учиться
#
# Реальное слово: веником	\	Корректное исправление: веником
# Предсказание: великом
#
# Реальное слово: плинтуса	\	Корректное исправление: плинтуса
# Предсказание: плинтусах
#
# Реальное слово: нравиццо	\	Корректное исправление: нравится
# Предсказание: нравиццо
#
# Реальное слово: посдравляю	\	Корректное исправление: поздравляю
# Предсказание: поздравляют
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: погда	\	Корректное исправление: погода
# Предсказание: когда
#
# Реальное слово: осеннему	\	Корректное исправление: осеннему
# Предсказание: осенней
#
# Реальное слово: кааак	\	Корректное исправление: как
# Предсказание: казак
#
# Реальное слово: каааак	\	Корректное исправление: как
# Предсказание: казак
#
# Реальное слово: неискренное	\	Корректное исправление: неискреннее
# Предсказание: неискреннего
#
# Реальное слово: воооот	\	Корректное исправление: вот
# Предсказание: ворот
#
# Реальное слово: саб	\	Корректное исправление: саб
# Предсказание: сам
#
# Реальное слово: понаобещщал	\	Корректное исправление: понаобещал
# Предсказание: понаобещщал
#
# Реальное слово: запариваться	\	Корректное исправление: запариваться
# Предсказание: спариваться
#
# Реальное слово: неуравновешено	\	Корректное исправление: неуравновешенно
# Предсказание: неуравновешен
#
# Реальное слово: центрм	\	Корректное исправление: центром
# Предсказание: центр
#
# Реальное слово: вильно	\	Корректное исправление: сильно
# Предсказание: вильно
#
# Реальное слово: влева	\	Корректное исправление: влево
# Предсказание: слева
#
# Реальное слово: рассказжу	\	Корректное исправление: расскажу
# Предсказание: рассказу
#
# Реальное слово: покажиииии	\	Корректное исправление: покажи
# Предсказание: покажиииии
#
# Реальное слово: поженаем	\	Корректное исправление: пожинаем
# Предсказание: пожелает
#
# Реальное слово: забегаю	\	Корректное исправление: забегаю
# Предсказание: забегах
#
# Реальное слово: болтаю	\	Корректное исправление: болтаю
# Предсказание: болта
#
# Реальное слово: девочнками	\	Корректное исправление: девчонками
# Предсказание: девочками
#
# Реальное слово: радужном	\	Корректное исправление: радужном
# Предсказание: радужной
#
# Реальное слово: маршрутки	\	Корректное исправление: маршрутки
# Предсказание: маршрутка
#
# Реальное слово: финбана	\	Корректное исправление: финбана
# Предсказание: финала
#
# Реальное слово: толкаться	\	Корректное исправление: толкаться
# Предсказание: потолкаться
#
# Реальное слово: торбой	\	Корректное исправление: торбой
# Предсказание: тобой
#
# Реальное слово: 1930-ые	\	Корректное исправление: 1930-ые
# Предсказание: 1930-е
#
# Реальное слово: собсно	\	Корректное исправление: собственно
# Предсказание: соосно
#
# Реальное слово: апять	\	Корректное исправление: опять
# Предсказание: пять
#
# Реальное слово: мной	\	Корректное исправление: мне
# Предсказание: мной
#
# Реальное слово: будеш	\	Корректное исправление: будешь
# Предсказание: будет
#
# Реальное слово: сваи	\	Корректное исправление: свои
# Предсказание: сваи
#
# Реальное слово: аписывать	\	Корректное исправление: описывать
# Предсказание: записывать
#
# Реальное слово: шоб	\	Корректное исправление: чтоб
# Предсказание: об
#
# Реальное слово: рассчет	\	Корректное исправление: расчет
# Предсказание: рассвет
#
# Реальное слово: берем	\	Корректное исправление: берем
# Предсказание: берег
#
# Реальное слово: ничо	\	Корректное исправление: ничего
# Предсказание: нико
#
# Реальное слово: совлаладав	\	Корректное исправление: совладав
# Предсказание: совлаладав
#
# Реальное слово: тусуется	\	Корректное исправление: тусуется
# Предсказание: рисуется
#
# Реальное слово: прочитавшие	\	Корректное исправление: прочитавшие
# Предсказание: прочитавший
#
# Реальное слово: жизни	\	Корректное исправление: жизнь
# Предсказание: жизни
#
# Реальное слово: денется	\	Корректное исправление: денется
# Предсказание: дерется
#
# Реальное слово: подворотни	\	Корректное исправление: подворотни
# Предсказание: подворотнями
#
# Реальное слово: лязгом	\	Корректное исправление: лязгом
# Предсказание: мозгом
#
# Реальное слово: собссно	\	Корректное исправление: собственно
# Предсказание: собрано
#
# Реальное слово: готовься	\	Корректное исправление: готовься
# Предсказание: готовится
#
# Реальное слово: подешевеет	\	Корректное исправление: подешевеет
# Предсказание: подешевле
#
# Реальное слово: квартирку	\	Корректное исправление: квартирку
# Предсказание: квартиру

# %% [markdown]
# Сначала для симспела попробуем добавить фильтрацию по морфологии, так как часть ошибок завязано чисто на ней:
#
# ```Реальное слово: пояним	\	Корректное исправление: поясним
# Предсказание: одним
#
# => часть речи
#
# ```Реальное слово: дорожно-транспортных	\	Корректное исправление: дорожно-транспортных
# Предсказание: дорожно-транспортные
#
# => падеж
#
# Реальное слово: иностранка	\	Корректное исправление: иностранка
# Предсказание: иностранца
# => род

# %%
import math
from functools import lru_cache
import pymorphy3

# %%
morph = pymorphy3.MorphAnalyzer()

# %%
def ending_match(word1, word2, length=3):
    return int(word1[-length:] == word2[-length:])


def grammar_match(word1, word2, ending=False):
    parse1 = morph.parse(word1)[0]
    parse2 = morph.parse(word2)[0]

    cumm = 0
    
    if parse1.tag.POS == parse2.tag.POS:
        cumm += 1

    gender_match = (parse1.tag.gender == parse2.tag.gender)
    if gender_match:
        cumm += 1

    number_match = (parse1.tag.number == parse2.tag.number)
    if number_match:
        cumm += 1
    
    case_match = (parse1.tag.case == parse2.tag.case)
    if case_match: 
        cumm += 1 

    if ending:
        cumm += ending_match(word1, word2)
    return cumm


def candidate_score(input_word, candidate, dictionary, weight=None, ending=False):
    freq = dictionary.get(candidate, 0)
    gm = grammar_match(input_word, candidate, ending=ending)
    if weight is None:
        dist =  textdistance.damerau_levenshtein(input_word, candidate)
    else:
        dist = weighted_damerau_levenshtein(input_word, candidate, costs=weight)

    score = (candidate, dist, freq, gm)
    return score

# %%
def correct_word(input_word, dictionary, deletion_index, max_distance=2, ending=False, weight=None):
    candidates = set()
    
    if input_word in dictionary:
        candidates.add(input_word)
    
    deletes = generate_deletes(input_word, max_distance=max_distance)
    for d in deletes:
        if d in deletion_index:
            candidates.update(deletion_index[d])
    
    if not candidates:
        return input_word
    
    scored = [(candidate_score(input_word, c, dictionary, weight=weight)) for c in candidates]
    scored.sort(key=lambda x: (x[1], -x[2], -x[3], x[0]))
    return scored[0][0]

# %%
def correct_text_with_symspell_morph(text, vocab, deletion_index, max_distance=2, ending=False, weight=None):
    tokens = normalize(text)
    corrected_tokens = []

    for word in tokens:
        if predict_mistaken(word, vocab):
            candidate = correct_word(word, vocab, deletion_index, max_distance=max_distance, ending=ending, weight=weight)
            corrected_tokens.append(candidate if candidate else word)
        else:
            corrected_tokens.append(word)

    return " ".join(corrected_tokens)

# %%
y_true_new = []
y_actual_new = []
y_preds_new = []

for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])

    corrected = correct_text_with_symspell_morph(bad[i], dictionary, deletion_index, max_distance=2).split()

    for j in range(len(word_pairs)):
        true_word = word_pairs[j][0]
        actual_word = word_pairs[j][1]
        pred = corrected[j]

        y_true_new.append(true_word)
        y_actual_new.append(actual_word)
        y_preds_new.append(pred)
# Out:
# 100%|██████████| 915/915 [00:28<00:00, 31.89it/s]

# %%
metrics = calculate_metrics(y_true_new, y_actual_new, y_preds_new)
metrics
# Out:
# {'total_accuracy': 0.871735867933967,
#  'fixed_mistakes': 0.5232919254658385,
#  'broken_correct_words': 0.07671988055587459}

# %% [markdown]
# С помощью добавления грамматики и замены функции с обычного Левенштейна, на доработку с транспозицией (Дамерау-Левенштейн) получилось чуток поднять качество (на 12 пунктов...):

# %%
print(f"Правильных разборов у обычной: {0.870935467733867*len(y_true_new)}")
print(f"Правильных разборов у улучшенной: {0.871735867933967*len(y_true_new)}")
# Out:
# Правильных разборов у обычной: 8705.0
# Правильных разборов у улучшенной: 8713.0

# %%
for true_pred, model_pred, actual_pred in zip(y_true_new, y_preds_new, y_actual_new):
    if true_pred != model_pred:
        print(f"Реальное слово: {actual_pred}\t\\\tКорректное исправление: {true_pred:}")
        print(f"Предсказание: {model_pred}", end='\n\n')
# Out:
# Реальное слово: симпатичнейшое	\	Корректное исправление: симпатичнейшее
# Предсказание: симпатичнейшое
#
# Реальное слово: шпионское	\	Корректное исправление: шпионское
# Предсказание: шпионской
#
# Реальное слово: гламурный	\	Корректное исправление: гламурный
# Предсказание: гламурным
#
# Реальное слово: clap	\	Корректное исправление: clap
# Предсказание: cap
#
# Реальное слово: опофеозом	\	Корректное исправление: апофеозом
# Предсказание: опофеозом
#
# Реальное слово: услышанная	\	Корректное исправление: услышанная
# Предсказание: услышанное
#
# Реальное слово: пояним	\	Корректное исправление: поясним
# Предсказание: одним
#
# Реальное слово: язычки	\	Корректное исправление: язычки
# Предсказание: языки
#
# Реальное слово: оччччень	\	Корректное исправление: очень
# Предсказание: оччччень
#
# Реальное слово: нащщот	\	Корректное исправление: насчет
# Предсказание: нагота
#
# Реальное слово: сетуют	\	Корректное исправление: сетуют
# Предсказание: сетует
#
# Реальное слово: основая	\	Корректное исправление: основная
# Предсказание: основан
#
# Реальное слово: дорожно-транспортных	\	Корректное исправление: дорожно-транспортных
# Предсказание: дорожно-транспортные
#
# Реальное слово: вобщем	\	Корректное исправление: в
# Предсказание: общем
#
# Реальное слово: как	\	Корректное исправление: общем
# Предсказание: как
#
# Реальное слово: вы	\	Корректное исправление: как
# Предсказание: вы
#
# Реальное слово: знаете	\	Корректное исправление: вы
# Предсказание: знаете
#
# Реальное слово: из	\	Корректное исправление: знаете
# Предсказание: из
#
# Реальное слово: моего	\	Корректное исправление: из
# Предсказание: моего
#
# Реальное слово: не	\	Корректное исправление: моего
# Предсказание: не
#
# Реальное слово: давнего	\	Корректное исправление: недавнего
# Предсказание: давнего
#
# Реальное слово: почте.ру	\	Корректное исправление: почте.ру
# Предсказание: портеру
#
# Реальное слово: рите	\	Корректное исправление: рите
# Предсказание: риме
#
# Реальное слово: снятся	\	Корректное исправление: снятся
# Предсказание: снялся
#
# Реальное слово: патаму	\	Корректное исправление: потому
# Предсказание: патуму
#
# Реальное слово: шта	\	Корректное исправление: что
# Предсказание: эта
#
# Реальное слово: пытаюсь	\	Корректное исправление: пытаюсь
# Предсказание: пытаясь
#
# Реальное слово: дубраве	\	Корректное исправление: дубраве
# Предсказание: дубрава
#
# Реальное слово: люминала	\	Корректное исправление: люминала
# Предсказание: номинала
#
# Реальное слово: поффтыкав	\	Корректное исправление: повтыкав
# Предсказание: поффтыкав
#
# Реальное слово: билетным	\	Корректное исправление: билетным
# Предсказание: билетные
#
# Реальное слово: кассам	\	Корректное исправление: кассам
# Предсказание: классам
#
# Реальное слово: соре	\	Корректное исправление: ссоре
# Предсказание: соре
#
# Реальное слово: выговаривает	\	Корректное исправление: выговаривает
# Предсказание: уговаривает
#
# Реальное слово: кредиток	\	Корректное исправление: кредиток
# Предсказание: кредитов
#
# Реальное слово: кормилицу	\	Корректное исправление: кормилицу
# Предсказание: кормилица
#
# Реальное слово: молодеж	\	Корректное исправление: молодежь
# Предсказание: молодеж
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: вешать	\	Корректное исправление: навешать
# Предсказание: вешать
#
# Реальное слово: оплеух	\	Корректное исправление: оплеух
# Предсказание: плену
#
# Реальное слово: пивоварах	\	Корректное исправление: пивоварах
# Предсказание: пивовара
#
# Реальное слово: эт	\	Корректное исправление: это
# Предсказание: эт
#
# Реальное слово: канешна	\	Корректное исправление: конечно
# Предсказание: кантона
#
# Реальное слово: зажог	\	Корректное исправление: зажег
# Предсказание: залог
#
# Реальное слово: павзрослому	\	Корректное исправление: по-взрослому
# Предсказание: павзрослому
#
# Реальное слово: прыщами	\	Корректное исправление: прыщами
# Предсказание: правами
#
# Реальное слово: слег	\	Корректное исправление: слег
# Предсказание: олег
#
# Реальное слово: ветрянка	\	Корректное исправление: ветрянка
# Предсказание: ветряка
#
# Реальное слово: малолетнии	\	Корректное исправление: малолетние
# Предсказание: малолетний
#
# Реальное слово: наркоманы	\	Корректное исправление: наркоманы
# Предсказание: наркомана
#
# Реальное слово: хихикать	\	Корректное исправление: хихикать
# Предсказание: химикаты
#
# Реальное слово: молодеж	\	Корректное исправление: молодежь
# Предсказание: молодеж
#
# Реальное слово: ощушаю	\	Корректное исправление: ощущаю
# Предсказание: ощущал
#
# Реальное слово: монголойдом	\	Корректное исправление: монголоидом
# Предсказание: монголойдом
#
# Реальное слово: молчала	\	Корректное исправление: молчала
# Предсказание: молчал
#
# Реальное слово: молчю	\	Корректное исправление: молчу
# Предсказание: молча
#
# Реальное слово: триатлон	\	Корректное исправление: триатлон
# Предсказание: триатлону
#
# Реальное слово: сашкой	\	Корректное исправление: сашкой
# Предсказание: самкой
#
# Реальное слово: плоскостопых	\	Корректное исправление: плоскостопых
# Предсказание: плоскостных
#
# Реальное слово: обълись	\	Корректное исправление: объелись
# Предсказание: обелиск
#
# Реальное слово: распрашивая	\	Корректное исправление: расспрашивая
# Предсказание: раскрашивая
#
# Реальное слово: зубодробительня	\	Корректное исправление: зубодробительная
# Предсказание: зубодробительня
#
# Реальное слово: гребенка	\	Корректное исправление: гребенка
# Предсказание: ребенка
#
# Реальное слово: каааак	\	Корректное исправление: как
# Предсказание: казак
#
# Реальное слово: изводить	\	Корректное исправление: изводить
# Предсказание: взводить
#
# Реальное слово: писмена	\	Корректное исправление: письмена
# Предсказание: пимена
#
# Реальное слово: дороговато	\	Корректное исправление: дороговато
# Предсказание: роговатое
#
# Реальное слово: штучка	\	Корректное исправление: штучка
# Предсказание: штучки
#
# Реальное слово: самойто	\	Корректное исправление: самой-то
# Предсказание: самойло
#
# Реальное слово: тул	\	Корректное исправление: тут
# Предсказание: тул
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: тока	\	Корректное исправление: только
# Предсказание: тока
#
# Реальное слово: мечталось	\	Корректное исправление: мечталось
# Предсказание: металась
#
# Реальное слово: сынишке	\	Корректное исправление: сынишке
# Предсказание: сынишка
#
# Реальное слово: покорми	\	Корректное исправление: покорми
# Предсказание: покоями
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: доделала	\	Корректное исправление: доделала
# Предсказание: сделала
#
# Реальное слово: яся	\	Корректное исправление: яся
# Предсказание: вся
#
# Реальное слово: стараюсь	\	Корректное исправление: стараюсь
# Предсказание: стараясь
#
# Реальное слово: озаботил	\	Корректное исправление: озаботил
# Предсказание: заботила
#
# Реальное слово: никада	\	Корректное исправление: никогда
# Предсказание: никуда
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: симаатическая	\	Корректное исправление: симпатическая
# Предсказание: семантическая
#
# Реальное слово: потовые	\	Корректное исправление: потовые
# Предсказание: почтовые
#
# Реальное слово: слюнные	\	Корректное исправление: слюнные
# Предсказание: слюнных
#
# Реальное слово: радовала	\	Корректное исправление: радовала
# Предсказание: ратовала
#
# Реальное слово: варикоза	\	Корректное исправление: варикоза
# Предсказание: варикапа
#
# Реальное слово: рассчете	\	Корректное исправление: расчете
# Предсказание: рассвете
#
# Реальное слово: купим	\	Корректное исправление: купим
# Предсказание: купил
#
# Реальное слово: пойдем	\	Корректное исправление: пойдем
# Предсказание: пойдет
#
# Реальное слово: navision	\	Корректное исправление: navision
# Предсказание: division
#
# Реальное слово: axapta	\	Корректное исправление: axapta
# Предсказание: alata
#
# Реальное слово: расжился	\	Корректное исправление: разжился
# Предсказание: разбился
#
# Реальное слово: сабжа	\	Корректное исправление: сабжа
# Предсказание: саба
#
# Реальное слово: обезумевшая	\	Корректное исправление: обезумевшая
# Предсказание: обезумевший
#
# Реальное слово: раскидала	\	Корректное исправление: раскидала
# Предсказание: раскидал
#
# Реальное слово: пользоваццо	\	Корректное исправление: пользоваться
# Предсказание: пользоваццо
#
# Реальное слово: бредовую	\	Корректное исправление: бредовую
# Предсказание: бедовую
#
# Реальное слово: доев	\	Корректное исправление: доев
# Предсказание: боев
#
# Реальное слово: покатавшись	\	Корректное исправление: покатавшись
# Предсказание: оказавшись
#
# Реальное слово: креатифф	\	Корректное исправление: креатив
# Предсказание: крещатик
#
# Реальное слово: экономикса	\	Корректное исправление: экономикса
# Предсказание: экономика
#
# Реальное слово: челка	\	Корректное исправление: челка
# Предсказание: белка
#
# Реальное слово: отросла	\	Корректное исправление: отросла
# Предсказание: обросла
#
# Реальное слово: стричься	\	Корректное исправление: стричься
# Предсказание: строиться
#
# Реальное слово: однимает	\	Корректное исправление: обнимает
# Предсказание: поднимает
#
# Реальное слово: эриды	\	Корректное исправление: эриды
# Предсказание: фриды
#
# Реальное слово: правила	\	Корректное исправление: правило
# Предсказание: правила
#
# Реальное слово: даешь	\	Корректное исправление: даешь
# Предсказание: дашь
#
# Реальное слово: удивленные	\	Корректное исправление: удивленные
# Предсказание: удивленный
#
# Реальное слово: нисхождении	\	Корректное исправление: нисхождении
# Предсказание: нисхождение
#
# Реальное слово: нмного	\	Корректное исправление: немного
# Предсказание: много
#
# Реальное слово: открыывю	\	Корректное исправление: открываю
# Предсказание: открытию
#
# Реальное слово: высыпвние	\	Корректное исправление: высыпание
# Предсказание: высыпания
#
# Реальное слово: забавен	\	Корректное исправление: забавен
# Предсказание: занавес
#
# Реальное слово: хламину	\	Корректное исправление: хламину
# Предсказание: ламину
#
# Реальное слово: пяный	\	Корректное исправление: пьяный
# Предсказание: пятый
#
# Реальное слово: фотка	\	Корректное исправление: фотка
# Предсказание: фока
#
# Реальное слово: подоплеке	\	Корректное исправление: подоплеке
# Предсказание: подоплёка
#
# Реальное слово: каком-никаком	\	Корректное исправление: каком-никаком
# Предсказание: какой-никакой
#
# Реальное слово: напряге	\	Корректное исправление: напряге
# Предсказание: напряги
#
# Реальное слово: каталась	\	Корректное исправление: каталась
# Предсказание: казалась
#
# Реальное слово: собстно	\	Корректное исправление: собственно
# Предсказание: собрано
#
# Реальное слово: рясах	\	Корректное исправление: рясах
# Предсказание: рядах
#
# Реальное слово: огроменных	\	Корректное исправление: огроменных
# Предсказание: опрошенных
#
# Реальное слово: неососознанно	\	Корректное исправление: неосознанно
# Предсказание: неосознанное
#
# Реальное слово: сохраю	\	Корректное исправление: сохраню
# Предсказание: собрал
#
# Реальное слово: сыро	\	Корректное исправление: сыро
# Предсказание: сыр
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: ат	\	Корректное исправление: ад
# Предсказание: ат
#
# Реальное слово: никада	\	Корректное исправление: никогда
# Предсказание: никуда
#
# Реальное слово: угадаете	\	Корректное исправление: угадаете
# Предсказание: угасает
#
# Реальное слово: пожже	\	Корректное исправление: позже
# Предсказание: пожже
#
# Реальное слово: материей	\	Корректное исправление: материей
# Предсказание: матерей
#
# Реальное слово: прокорм	\	Корректное исправление: прокорм
# Предсказание: сроком
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: джойстер	\	Корректное исправление: джойстер
# Предсказание: джойстик
#
# Реальное слово: молчу	\	Корректное исправление: молчу
# Предсказание: мочу
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: самыи	\	Корректное исправление: самый
# Предсказание: самым
#
# Реальное слово: гадости	\	Корректное исправление: гадости
# Предсказание: радости
#
# Реальное слово: но	\	Корректное исправление: на
# Предсказание: но
#
# Реальное слово: обидели	\	Корректное исправление: обидели
# Предсказание: обители
#
# Реальное слово: рекоммендация	\	Корректное исправление: рекомендации
# Предсказание: рекомендация
#
# Реальное слово: напректировали	\	Корректное исправление: напроектировали
# Предсказание: проектировали
#
# Реальное слово: раскину	\	Корректное исправление: раскину
# Предсказание: раскина
#
# Реальное слово: сплю	\	Корректное исправление: сплю
# Предсказание: салю
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: снежинка	\	Корректное исправление: снежинка
# Предсказание: снежинки
#
# Реальное слово: застрелиться	\	Корректное исправление: застрелиться
# Предсказание: застрелился
#
# Реальное слово: расплющиваются	\	Корректное исправление: расплющиваются
# Предсказание: расплачиваются
#
# Реальное слово: афальтоукладчик	\	Корректное исправление: асфальтоукладчик
# Предсказание: афальтоукладчик
#
# Реальное слово: проясненным	\	Корректное исправление: проясненным
# Предсказание: проявленным
#
# Реальное слово: кчакчество	\	Корректное исправление: качество
# Предсказание: качеством
#
# Реальное слово: зажатия	\	Корректное исправление: зажатия
# Предсказание: зачатия
#
# Реальное слово: пупковой	\	Корректное исправление: пупковой
# Предсказание: пусковой
#
# Реальное слово: бегущая	\	Корректное исправление: бегущая
# Предсказание: берущая
#
# Реальное слово: унываю	\	Корректное исправление: унываю
# Предсказание: уповаю
#
# Реальное слово: прикодьные	\	Корректное исправление: прикольные
# Предсказание: природные
#
# Реальное слово: собстно	\	Корректное исправление: собственно
# Предсказание: собрано
#
# Реальное слово: помотрть	\	Корректное исправление: посмотреть
# Предсказание: помогать
#
# Реальное слово: пприкольные	\	Корректное исправление: прикольные
# Предсказание: привольные
#
# Реальное слово: начьните	\	Корректное исправление: начните
# Предсказание: значение
#
# Реальное слово: онвыгребает	\	Корректное исправление: он
# Предсказание: онвыгребает
#
# Реальное слово: ее	\	Корректное исправление: выгребает
# Предсказание: ее
#
# Реальное слово: из	\	Корректное исправление: ее
# Предсказание: из
#
# Реальное слово: под	\	Корректное исправление: из-под
# Предсказание: под
#
# Реальное слово: небыло	\	Корректное исправление: не
# Предсказание: немало
#
# Реальное слово: никогда	\	Корректное исправление: было
# Предсказание: никогда
#
# Реальное слово: любви	\	Корректное исправление: никогда
# Предсказание: любви
#
# Реальное слово: то	\	Корректное исправление: любви-то
# Предсказание: то
#
# Реальное слово: деловито	\	Корректное исправление: деловито
# Предсказание: делового
#
# Реальное слово: дружился	\	Корректное исправление: дружился
# Предсказание: сдружился
#
# Реальное слово: начальнице	\	Корректное исправление: начальнице
# Предсказание: начальнике
#
# Реальное слово: заити	\	Корректное исправление: зайти
# Предсказание: гаити
#
# Реальное слово: вконтакт	\	Корректное исправление: вконтакт
# Предсказание: контакт
#
# Реальное слово: ненавидшь	\	Корректное исправление: ненавидишь
# Предсказание: ненависть
#
# Реальное слово: мыслящаю	\	Корректное исправление: мыслящая
# Предсказание: мыслящей
#
# Реальное слово: убрть	\	Корректное исправление: убрать
# Предсказание: убить
#
# Реальное слово: мишуру	\	Корректное исправление: мишуру
# Предсказание: мицуру
#
# Реальное слово: процедудура	\	Корректное исправление: процедура
# Предсказание: процедурам
#
# Реальное слово: гордуму	\	Корректное исправление: гордуму
# Предсказание: госдуму
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: свредничала	\	Корректное исправление: свредничала
# Предсказание: посредничал
#
# Реальное слово: продавщицу	\	Корректное исправление: продавщицу
# Предсказание: продавщица
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: бесит	\	Корректное исправление: бесит
# Предсказание: бежит
#
# Реальное слово: увольняться	\	Корректное исправление: увольняться
# Предсказание: увольняется
#
# Реальное слово: сером	\	Корректное исправление: серой
# Предсказание: сером
#
# Реальное слово: рисунко	\	Корректное исправление: рисунком
# Предсказание: рисунок
#
# Реальное слово: упоением	\	Корректное исправление: упоением
# Предсказание: умением
#
# Реальное слово: сухинова	\	Корректное исправление: сухинова
# Предсказание: суханова
#
# Реальное слово: продолжения	\	Корректное исправление: продолжение
# Предсказание: продолжения
#
# Реальное слово: бякость	\	Корректное исправление: бякость
# Предсказание: мякость
#
# Реальное слово: взываю	\	Корректное исправление: взываю
# Предсказание: взывал
#
# Реальное слово: спичечного	\	Корректное исправление: спичечного
# Предсказание: почечного
#
# Реальное слово: тасовоать	\	Корректное исправление: тасовать
# Предсказание: фасовать
#
# Реальное слово: опаздываю	\	Корректное исправление: опаздываю
# Предсказание: опаздывал
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: страааашно	\	Корректное исправление: страшно
# Предсказание: страааашно
#
# Реальное слово: обогреватель	\	Корректное исправление: обогреватель
# Предсказание: обозреватель
#
# Реальное слово: окромя	\	Корректное исправление: окромя
# Предсказание: кроме
#
# Реальное слово: канешна	\	Корректное исправление: конечно
# Предсказание: кантона
#
# Реальное слово: превратит	\	Корректное исправление: превратит
# Предсказание: превратить
#
# Реальное слово: фарш	\	Корректное исправление: фарш
# Предсказание: марш
#
# Реальное слово: празнег	\	Корректное исправление: праздник
# Предсказание: разбег
#
# Реальное слово: жуть	\	Корректное исправление: жуть
# Предсказание: путь
#
# Реальное слово: встретицца	\	Корректное исправление: встретиться
# Предсказание: встретила
#
# Реальное слово: нажусь	\	Корректное исправление: нахожусь
# Предсказание: нажать
#
# Реальное слово: непонятном	\	Корректное исправление: непонятном
# Предсказание: непонятно
#
# Реальное слово: паршивое	\	Корректное исправление: паршивое
# Предсказание: паровое
#
# Реальное слово: закипания	\	Корректное исправление: закипания
# Предсказание: залипания
#
# Реальное слово: сайлау	\	Корректное исправление: сайлау
# Предсказание: жайлау
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: брыкаться	\	Корректное исправление: брыкаться
# Предсказание: бросаться
#
# Реальное слово: визжать	\	Корректное исправление: визжать
# Предсказание: вызвать
#
# Реальное слово: дооолго	\	Корректное исправление: долго
# Предсказание: дорого
#
# Реальное слово: садится	\	Корректное исправление: садиться
# Предсказание: садится
#
# Реальное слово: залпы	\	Корректное исправление: залпы
# Предсказание: залы
#
# Реальное слово: беглянок	\	Корректное исправление: беглянок
# Предсказание: белянок
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: календарику	\	Корректное исправление: календарику
# Предсказание: календариков
#
# Реальное слово: зачеркиваю	\	Корректное исправление: зачеркиваю
# Предсказание: задерживаю
#
# Реальное слово: крестики	\	Корректное исправление: крестики
# Предсказание: крестик
#
# Реальное слово: чудябриков	\	Корректное исправление: чудябриков
# Предсказание: чубариков
#
# Реальное слово: полюбому	\	Корректное исправление: по-любому
# Предсказание: полному
#
# Реальное слово: ослуживание	\	Корректное исправление: ослуживание
# Предсказание: обслуживание
#
# Реальное слово: ищите	\	Корректное исправление: ищете
# Предсказание: ищите
#
# Реальное слово: какова	\	Корректное исправление: какого
# Предсказание: какова
#
# Реальное слово: раена	\	Корректное исправление: района
# Предсказание: равна
#
# Реальное слово: объясни	\	Корректное исправление: объясни
# Предсказание: объяснил
#
# Реальное слово: сначало	\	Корректное исправление: сначала
# Предсказание: начало
#
# Реальное слово: пролжительность	\	Корректное исправление: продолжительность
# Предсказание: пролжительность
#
# Реальное слово: прикупить	\	Корректное исправление: прикупить
# Предсказание: приступить
#
# Реальное слово: продул	\	Корректное исправление: продул
# Предсказание: продал
#
# Реальное слово: угошали	\	Корректное исправление: угощали
# Предсказание: угрожали
#
# Реальное слово: подделаная	\	Корректное исправление: подделанная
# Предсказание: поддельная
#
# Реальное слово: неаутентична	\	Корректное исправление: неаутентична
# Предсказание: аутентичная
#
# Реальное слово: подрбный	\	Корректное исправление: подробный
# Предсказание: подобный
#
# Реальное слово: обдумывю	\	Корректное исправление: обдумываю
# Предсказание: обдумывал
#
# Реальное слово: постинги	\	Корректное исправление: постинги
# Предсказание: постигли
#
# Реальное слово: вкусному	\	Корректное исправление: вкусному
# Предсказание: вкусное
#
# Реальное слово: познакомицца	\	Корректное исправление: познакомиться
# Предсказание: познакомила
#
# Реальное слово: большое	\	Корректное исправление: большой
# Предсказание: большое
#
# Реальное слово: шульга	\	Корректное исправление: шульга
# Предсказание: шульца
#
# Реальное слово: зимариным	\	Корректное исправление: зимариным
# Предсказание: зимарины
#
# Реальное слово: незнаю	\	Корректное исправление: не
# Предсказание: ненад
#
# Реальное слово: ходить	\	Корректное исправление: знаю
# Предсказание: ходить
#
# Реальное слово: на	\	Корректное исправление: ходить
# Предсказание: на
#
# Реальное слово: море	\	Корректное исправление: на
# Предсказание: море
#
# Реальное слово: делать	\	Корректное исправление: море
# Предсказание: делать
#
# Реальное слово: ремонт	\	Корректное исправление: делать
# Предсказание: ремонт
#
# Реальное слово: кого	\	Корректное исправление: ремонт
# Предсказание: кого
#
# Реальное слово: нибудь	\	Корректное исправление: кого-нибудь
# Предсказание: никуда
#
# Реальное слово: насмотрелся	\	Корректное исправление: насмотрелся
# Предсказание: осмотрелся
#
# Реальное слово: лосяра	\	Корректное исправление: лосяра
# Предсказание: осера
#
# Реальное слово: сроду	\	Корректное исправление: сроду
# Предсказание: роду
#
# Реальное слово: ощастливленный	\	Корректное исправление: осчастливленный
# Предсказание: ощастливленный
#
# Реальное слово: выхожу	\	Корректное исправление: выхожу
# Предсказание: выходу
#
# Реальное слово: решаем	\	Корректное исправление: решаем
# Предсказание: решает
#
# Реальное слово: левонтием	\	Корректное исправление: левонтием
# Предсказание: леонтием
#
# Реальное слово: оным	\	Корректное исправление: оным
# Предсказание: иным
#
# Реальное слово: коньяком	\	Корректное исправление: коньяком
# Предсказание: коньком
#
# Реальное слово: колой	\	Корректное исправление: колой
# Предсказание: школой
#
# Реальное слово: спрашиваю	\	Корректное исправление: спрашиваю
# Предсказание: спрашивал
#
# Реальное слово: поведйте	\	Корректное исправление: поведайте
# Предсказание: поведать
#
# Реальное слово: плиз	\	Корректное исправление: плиз
# Предсказание: близ
#
# Реальное слово: тока	\	Корректное исправление: только
# Предсказание: тока
#
# Реальное слово: сдай	\	Корректное исправление: сдай
# Предсказание: сдан
#
# Реальное слово: сушит	\	Корректное исправление: сушит
# Предсказание: суши
#
# Реальное слово: притянулись	\	Корректное исправление: притянулись
# Предсказание: протянулись
#
# Реальное слово: нагибается	\	Корректное исправление: нагибается
# Предсказание: загибается
#
# Реальное слово: читаемсоть	\	Корректное исправление: читаемость
# Предсказание: читаемости
#
# Реальное слово: присоединаюсь	\	Корректное исправление: присоединяюсь
# Предсказание: присоединяясь
#
# Реальное слово: негодованию	\	Корректное исправление: негодованию
# Предсказание: негодование
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: отколотых	\	Корректное исправление: отколотых
# Предсказание: отколоть
#
# Реальное слово: вчерашним	\	Корректное исправление: вчерашним
# Предсказание: вчерашний
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: лосьончека	\	Корректное исправление: лосьончика
# Предсказание: лосьончека
#
# Реальное слово: пользовать	\	Корректное исправление: пользовать
# Предсказание: позировать
#
# Реальное слово: скучала	\	Корректное исправление: скучала
# Предсказание: скучали
#
# Реальное слово: девкам	\	Корректное исправление: девкам
# Предсказание: девам
#
# Реальное слово: двухполюсная	\	Корректное исправление: двухполюсная
# Предсказание: двухполосная
#
# Реальное слово: приезла	\	Корректное исправление: привезла
# Предсказание: приезда
#
# Реальное слово: чудище	\	Корректное исправление: чудище
# Предсказание: будище
#
# Реальное слово: просвестевшая	\	Корректное исправление: просвистевшая
# Предсказание: просвестевшая
#
# Реальное слово: оберутся	\	Корректное исправление: обернуться
# Предсказание: берутся
#
# Реальное слово: монсерат	\	Корректное исправление: монсерат
# Предсказание: монстра
#
# Реальное слово: матерю	\	Корректное исправление: матерю
# Предсказание: матери
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: лешил	\	Корректное исправление: лишил
# Предсказание: решил
#
# Реальное слово: касаемо	\	Корректное исправление: касаемо
# Предсказание: даваемо
#
# Реальное слово: эрендзи	\	Корректное исправление: эрендзи
# Предсказание: эфенди
#
# Реальное слово: норнштейн	\	Корректное исправление: норнштейн
# Предсказание: норштейн
#
# Реальное слово: гордится	\	Корректное исправление: гордиться
# Предсказание: гордится
#
# Реальное слово: посорилась	\	Корректное исправление: поссорилась
# Предсказание: покорилась
#
# Реальное слово: подружусь	\	Корректное исправление: подружусь
# Предсказание: подружить
#
# Реальное слово: какимнить	\	Корректное исправление: каким-нибудь
# Предсказание: какимнить
#
# Реальное слово: лж	\	Корректное исправление: лж
# Предсказание: л
#
# Реальное слово: выложу	\	Корректное исправление: выложу
# Предсказание: вылову
#
# Реальное слово: пластырь	\	Корректное исправление: пластырь
# Предсказание: пастырь
#
# Реальное слово: никоретте	\	Корректное исправление: никоретте
# Предсказание: николетт
#
# Реальное слово: дае	\	Корректное исправление: даже
# Предсказание: дае
#
# Реальное слово: нотную	\	Корректное исправление: нотную
# Предсказание: ночную
#
# Реальное слово: молчу	\	Корректное исправление: молчу
# Предсказание: мочу
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: паути	\	Корректное исправление: паутину
# Предсказание: пути
#
# Реальное слово: неридуманная	\	Корректное исправление: непридуманная
# Предсказание: неридуманная
#
# Реальное слово: перессказываю	\	Корректное исправление: пересказываю
# Предсказание: предсказываю
#
# Реальное слово: постараюсь	\	Корректное исправление: постараюсь
# Предсказание: постарался
#
# Реальное слово: подргрузился	\	Корректное исправление: подгрузился
# Предсказание: подргрузился
#
# Реальное слово: наберала	\	Корректное исправление: набирала
# Предсказание: набрала
#
# Реальное слово: девченки	\	Корректное исправление: девчонки
# Предсказание: шевченко
#
# Реальное слово: завижжали	\	Корректное исправление: завизжали
# Предсказание: завижжали
#
# Реальное слово: аккордах	\	Корректное исправление: аккордах
# Предсказание: аккорда
#
# Реальное слово: бэндом	\	Корректное исправление: бэндом
# Предсказание: бондом
#
# Реальное слово: невозмозможно	\	Корректное исправление: невозможно
# Предсказание: невозмозможно
#
# Реальное слово: привожу	\	Корректное исправление: привожу
# Предсказание: приводу
#
# Реальное слово: рассчет	\	Корректное исправление: расчет
# Предсказание: рассвет
#
# Реальное слово: пристегиваться	\	Корректное исправление: пристегиваться
# Предсказание: притягиваться
#
# Реальное слово: будеш	\	Корректное исправление: будешь
# Предсказание: будет
#
# Реальное слово: преинтерснейшее	\	Корректное исправление: преинтереснейшее
# Предсказание: преинтерснейшее
#
# Реальное слово: улыбнуло	\	Корректное исправление: улыбнуло
# Предсказание: хлынуло
#
# Реальное слово: дооолго	\	Корректное исправление: долго
# Предсказание: дорого
#
# Реальное слово: тянула	\	Корректное исправление: тянула
# Предсказание: тянул
#
# Реальное слово: батон	\	Корректное исправление: батон
# Предсказание: барон
#
# Реальное слово: пятиэтажки	\	Корректное исправление: пятиэтажки
# Предсказание: пятиэтажке
#
# Реальное слово: мя	\	Корректное исправление: я
# Предсказание: мя
#
# Реальное слово: привыкла	\	Корректное исправление: привыкла
# Предсказание: привыкли
#
# Реальное слово: именины	\	Корректное исправление: именины
# Предсказание: имениты
#
# Реальное слово: преодолеванием	\	Корректное исправление: преодолеванием
# Предсказание: переодеванием
#
# Реальное слово: протискивались	\	Корректное исправление: протискивались
# Предсказание: оттискивались
#
# Реальное слово: ползли	\	Корректное исправление: ползли
# Предсказание: полли
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: наплавалась	\	Корректное исправление: наплавалась
# Предсказание: направилась
#
# Реальное слово: што	\	Корректное исправление: что
# Предсказание: што
#
# Реальное слово: бомжи	\	Корректное исправление: бомжи
# Предсказание: божи
#
# Реальное слово: дерущиеся	\	Корректное исправление: дерущиеся
# Предсказание: дерущихся
#
# Реальное слово: бомжи	\	Корректное исправление: бомжи
# Предсказание: божи
#
# Реальное слово: осталалось	\	Корректное исправление: осталось
# Предсказание: оставалось
#
# Реальное слово: видюха	\	Корректное исправление: видюха
# Предсказание: видах
#
# Реальное слово: стратусы	\	Корректное исправление: статусы
# Предсказание: стратус
#
# Реальное слово: однокурссница	\	Корректное исправление: однокурсница
# Предсказание: одноклассница
#
# Реальное слово: аське	\	Корректное исправление: аське
# Предсказание: аске
#
# Реальное слово: лабораторках	\	Корректное исправление: лабораторках
# Предсказание: лабораторных
#
# Реальное слово: джинсовые	\	Корректное исправление: джинсовые
# Предсказание: джинсовыми
#
# Реальное слово: свалились	\	Корректное исправление: свалились
# Предсказание: сжалились
#
# Реальное слово: треснуть	\	Корректное исправление: треснуть
# Предсказание: треснуто
#
# Реальное слово: сначало	\	Корректное исправление: сначала
# Предсказание: начало
#
# Реальное слово: тарусу	\	Корректное исправление: тарусу
# Предсказание: тарасу
#
# Реальное слово: ессно	\	Корректное исправление: естественно
# Предсказание: ясно
#
# Реальное слово: созерцала	\	Корректное исправление: созерцала
# Предсказание: созерцал
#
# Реальное слово: попробую	\	Корректное исправление: попробую
# Предсказание: попробуй
#
# Реальное слово: измученная	\	Корректное исправление: измученная
# Предсказание: изученная
#
# Реальное слово: ознобом	\	Корректное исправление: ознобом
# Предсказание: особом
#
# Реальное слово: зарылась	\	Корректное исправление: зарылась
# Предсказание: закрылась
#
# Реальное слово: неделимое	\	Корректное исправление: неделимое
# Предсказание: неделимой
#
# Реальное слово: маршрутки	\	Корректное исправление: маршрутки
# Предсказание: маршрутка
#
# Реальное слово: битком	\	Корректное исправление: битком
# Предсказание: ситком
#
# Реальное слово: позаввчера	\	Корректное исправление: позавчера
# Предсказание: позаввчера
#
# Реальное слово: горбатую	\	Корректное исправление: горбатую
# Предсказание: горбатки
#
# Реальное слово: всплыло	\	Корректное исправление: всплыло
# Предсказание: всплыл
#
# Реальное слово: рученки	\	Корректное исправление: ручонки
# Предсказание: ученик
#
# Реальное слово: кнопачки	\	Корректное исправление: кнопочки
# Предсказание: копанки
#
# Реальное слово: профайле	\	Корректное исправление: профайле
# Предсказание: профиле
#
# Реальное слово: накатать	\	Корректное исправление: накатать
# Предсказание: наказать
#
# Реальное слово: прикладывам	\	Корректное исправление: прикладываем
# Предсказание: прикладывая
#
# Реальное слово: лобику	\	Корректное исправление: лобику
# Предсказание: логику
#
# Реальное слово: извлеченное	\	Корректное исправление: извлеченное
# Предсказание: извлеченные
#
# Реальное слово: осматриваем	\	Корректное исправление: осматриваем
# Предсказание: осматривает
#
# Реальное слово: следеите	\	Корректное исправление: следите
# Предсказание: следить
#
# Реальное слово: лежаки	\	Корректное исправление: лежаки
# Предсказание: лежали
#
# Реальное слово: денги	\	Корректное исправление: деньги
# Предсказание: денги
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: 3хчасовой	\	Корректное исправление: трехчасовой
# Предсказание: 3-часовой
#
# Реальное слово: кодексам	\	Корректное исправление: кодексам
# Предсказание: кодекса
#
# Реальное слово: заверив	\	Корректное исправление: заверив
# Предсказание: завершив
#
# Реальное слово: заверителей	\	Корректное исправление: заверителей
# Предсказание: заменителей
#
# Реальное слово: проставив	\	Корректное исправление: проставив
# Предсказание: поставив
#
# Реальное слово: поздравляю	\	Корректное исправление: поздравляю
# Предсказание: поздравляют
#
# Реальное слово: обрадовались	\	Корректное исправление: обрадовались
# Предсказание: образовались
#
# Реальное слово: доброжелательный	\	Корректное исправление: доброжелательный
# Предсказание: доброжелательным
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: накачанными	\	Корректное исправление: накачанными
# Предсказание: наказанными
#
# Реальное слово: прогматично	\	Корректное исправление: прагматично
# Предсказание: романтично
#
# Реальное слово: подумайте	\	Корректное исправление: подумайте
# Предсказание: подумать
#
# Реальное слово: общаються	\	Корректное исправление: общаются
# Предсказание: общаться
#
# Реальное слово: вобщем	\	Корректное исправление: в
# Предсказание: общем
#
# Реальное слово: сниццо	\	Корректное исправление: общем
# Предсказание: ницце
#
# Реальное слово: мне	\	Корректное исправление: снится
# Предсказание: мне
#
# Реальное слово: что	\	Корректное исправление: мне
# Предсказание: что
#
# Реальное слово: я	\	Корректное исправление: что
# Предсказание: я
#
# Реальное слово: нашел	\	Корректное исправление: я
# Предсказание: нашел
#
# Реальное слово: таки	\	Корректное исправление: нашел-таки
# Предсказание: таки
#
# Реальное слово: сволачи	\	Корректное исправление: сволочи
# Предсказание: валачи
#
# Реальное слово: подхожу	\	Корректное исправление: подхожу
# Предсказание: подходу
#
# Реальное слово: скребут	\	Корректное исправление: скребут
# Предсказание: скребки
#
# Реальное слово: апять	\	Корректное исправление: опять
# Предсказание: пять
#
# Реальное слово: ана	\	Корректное исправление: она
# Предсказание: ана
#
# Реальное слово: наливаю	\	Корректное исправление: наливаю
# Предсказание: наливают
#
# Реальное слово: кулере	\	Корректное исправление: кулере
# Предсказание: кулер
#
# Реальное слово: смешиваю	\	Корректное исправление: смешиваю
# Предсказание: смешивают
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: холооодная	\	Корректное исправление: холодная
# Предсказание: холооодная
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: доолго-дооолго-доооолго	\	Корректное исправление: долго-долго-долго
# Предсказание: доолго-дооолго-доооолго
#
# Реальное слово: юстировал	\	Корректное исправление: юстировал
# Предсказание: цитировал
#
# Реальное слово: элитному	\	Корректное исправление: элитному
# Предсказание: элитном
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: обструктивной	\	Корректное исправление: обструктивной
# Предсказание: конструктивной
#
# Реальное слово: ессно	\	Корректное исправление: естественно
# Предсказание: ясно
#
# Реальное слово: эксурсоводы	\	Корректное исправление: экскурсоводы
# Предсказание: экскурсовод
#
# Реальное слово: значет	\	Корректное исправление: значит
# Предсказание: знает
#
# Реальное слово: кено	\	Корректное исправление: кино
# Предсказание: кено
#
# Реальное слово: кедал	\	Корректное исправление: кидал
# Предсказание: дедал
#
# Реальное слово: кедалы	\	Корректное исправление: кидалы
# Предсказание: медали
#
# Реальное слово: подскажыте	\	Корректное исправление: подскажите
# Предсказание: подскажыте
#
# Реальное слово: зазырить	\	Корректное исправление: зазырить
# Предсказание: заверить
#
# Реальное слово: кровищщи	\	Корректное исправление: кровищи
# Предсказание: сокровищ
#
# Реальное слово: покапаться	\	Корректное исправление: покопаться
# Предсказание: показаться
#
# Реальное слово: выхи	\	Корректное исправление: выхи
# Предсказание: всхи
#
# Реальное слово: люда	\	Корректное исправление: люда
# Предсказание: люди
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: рекокомендую	\	Корректное исправление: рекомендую
# Предсказание: рекомендуют
#
# Реальное слово: проморзгло	\	Корректное исправление: промозгло
# Предсказание: проморзгло
#
# Реальное слово: муторно	\	Корректное исправление: муторно
# Предсказание: упорно
#
# Реальное слово: вообщем	\	Корректное исправление: в
# Предсказание: вообще
#
# Реальное слово: то	\	Корректное исправление: общем-то
# Предсказание: то
#
# Реальное слово: пекарской	\	Корректное исправление: пекарской
# Предсказание: пекарский
#
# Реальное слово: натертый	\	Корректное исправление: натертый
# Предсказание: нагретый
#
# Реальное слово: цедру	\	Корректное исправление: цедру
# Предсказание: педру
#
# Реальное слово: сушить	\	Корректное исправление: сушить
# Предсказание: судить
#
# Реальное слово: финдиректор	\	Корректное исправление: финдиректор
# Предсказание: гендиректор
#
# Реальное слово: напьешся	\	Корректное исправление: напьешься
# Предсказание: напиться
#
# Реальное слово: соратникам	\	Корректное исправление: соратникам
# Предсказание: соратника
#
# Реальное слово: дирижаблями	\	Корректное исправление: дирижаблями
# Предсказание: дирижаблях
#
# Реальное слово: нсущного	\	Корректное исправление: насущного
# Предсказание: научного
#
# Реальное слово: теоретизированое	\	Корректное исправление: теоретизированное
# Предсказание: теоретизирования
#
# Реальное слово: что	\	Корректное исправление: чтобы
# Предсказание: что
#
# Реальное слово: бы	\	Корректное исправление: больно
# Предсказание: бы
#
# Реальное слово: больно	\	Корректное исправление: не
# Предсказание: больно
#
# Реальное слово: небыло	\	Корректное исправление: было
# Предсказание: немало
#
# Реальное слово: мочь	\	Корректное исправление: мочь
# Предсказание: дочь
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: одно	\	Корректное исправление: одна
# Предсказание: одно
#
# Реальное слово: оооочень	\	Корректное исправление: очень
# Предсказание: оооочень
#
# Реальное слово: аццки	\	Корректное исправление: адски
# Предсказание: атаки
#
# Реальное слово: мааааммоооочкииии	\	Корректное исправление: мамочки
# Предсказание: мааааммоооочкииии
#
# Реальное слово: госов	\	Корректное исправление: госов
# Предсказание: годов
#
# Реальное слово: осложнен	\	Корректное исправление: осложнен
# Предсказание: осложнён
#
# Реальное слово: програмка	\	Корректное исправление: программка
# Предсказание: программа
#
# Реальное слово: преславутая	\	Корректное исправление: пресловутая
# Предсказание: преславутая
#
# Реальное слово: подкованная	\	Корректное исправление: подкованная
# Предсказание: подорванная
#
# Реальное слово: вырозился	\	Корректное исправление: выразился
# Предсказание: вывозился
#
# Реальное слово: напоменило	\	Корректное исправление: напомнило
# Предсказание: напоминало
#
# Реальное слово: стааарый	\	Корректное исправление: старый
# Предсказание: ста́рый
#
# Реальное слово: прийдя	\	Корректное исправление: придя
# Предсказание: пройдя
#
# Реальное слово: иракез	\	Корректное исправление: ирокез
# Предсказание: ираке
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: обьехав	\	Корректное исправление: объехав
# Предсказание: обещав
#
# Реальное слово: вьехал	\	Корректное исправление: въехал
# Предсказание: выехал
#
# Реальное слово: сандово	\	Корректное исправление: сандово
# Предсказание: заново
#
# Реальное слово: ля-ля	\	Корректное исправление: ля-ля
# Предсказание: ляля
#
# Реальное слово: ни	\	Корректное исправление: не
# Предсказание: ни
#
# Реальное слово: натянуто	\	Корректное исправление: натянуто
# Предсказание: натянуть
#
# Реальное слово: дарвиновского	\	Корректное исправление: дарвиновского
# Предсказание: сарвановского
#
# Реальное слово: какбы	\	Корректное исправление: как
# Предсказание: каабы
#
# Реальное слово: из	\	Корректное исправление: бы
# Предсказание: из
#
# Реальное слово: под	\	Корректное исправление: из-под
# Предсказание: под
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: новозаветняя	\	Корректное исправление: новозаветная
# Предсказание: новозаветной
#
# Реальное слово: рулит	\	Корректное исправление: рулит
# Предсказание: рули
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: обычныэ	\	Корректное исправление: обычные
# Предсказание: обычных
#
# Реальное слово: негодныэ	\	Корректное исправление: негодные
# Предсказание: негодным
#
# Реальное слово: любю	\	Корректное исправление: люблю
# Предсказание: любую
#
# Реальное слово: кефир	\	Корректное исправление: кефир
# Предсказание: зефир
#
# Реальное слово: глинтвейном	\	Корректное исправление: глинтвейном
# Предсказание: глинтвейна
#
# Реальное слово: неприглядно	\	Корректное исправление: неприглядно
# Предсказание: неприглядна
#
# Реальное слово: непредставительно	\	Корректное исправление: непредставительно
# Предсказание: непредставительным
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: бабежку	\	Корректное исправление: бабешку
# Предсказание: бабенко
#
# Реальное слово: промолчу	\	Корректное исправление: промолчу
# Предсказание: промолчал
#
# Реальное слово: трепа	\	Корректное исправление: трепа
# Предсказание: трека
#
# Реальное слово: нарыть	\	Корректное исправление: нарыть
# Предсказание: начать
#
# Реальное слово: жемчуженки	\	Корректное исправление: жемчужинки
# Предсказание: жемчужниц
#
# Реальное слово: постраее	\	Корректное исправление: постарее
# Предсказание: построен
#
# Реальное слово: дедуля	\	Корректное исправление: дедуля
# Предсказание: модуля
#
# Реальное слово: прийдя	\	Корректное исправление: придя
# Предсказание: пройдя
#
# Реальное слово: сачков	\	Корректное исправление: сачков
# Предсказание: саков
#
# Реальное слово: острое	\	Корректное исправление: острове
# Предсказание: острое
#
# Реальное слово: превратититься	\	Корректное исправление: превратиться
# Предсказание: превратититься
#
# Реальное слово: кляксу	\	Корректное исправление: кляксу
# Предсказание: классу
#
# Реальное слово: смяться	\	Корректное исправление: смяться
# Предсказание: сняться
#
# Реальное слово: разжижиться	\	Корректное исправление: разжижиться
# Предсказание: разжижаться
#
# Реальное слово: стечь	\	Корректное исправление: стечь
# Предсказание: степь
#
# Реальное слово: горестными	\	Корректное исправление: горестными
# Предсказание: окрестными
#
# Реальное слово: ссоримся	\	Корректное исправление: ссоримся
# Предсказание: ссорится
#
# Реальное слово: правоты	\	Корректное исправление: правоты
# Предсказание: правоте
#
# Реальное слово: фотки	\	Корректное исправление: фотки
# Предсказание: фоки
#
# Реальное слово: фоток	\	Корректное исправление: фоток
# Предсказание: поток
#
# Реальное слово: залил	\	Корректное исправление: залил
# Предсказание: забил
#
# Реальное слово: че	\	Корректное исправление: что
# Предсказание: че
#
# Реальное слово: ето	\	Корректное исправление: это
# Предсказание: что
#
# Реальное слово: утешюсь	\	Корректное исправление: утешаюсь
# Предсказание: утешить
#
# Реальное слово: ошпареных	\	Корректное исправление: ошпаренных
# Предсказание: спаренных
#
# Реальное слово: пыттаюсь	\	Корректное исправление: пытаюсь
# Предсказание: пытаясь
#
# Реальное слово: загоняю	\	Корректное исправление: загоняю
# Предсказание: загоняет
#
# Реальное слово: универа	\	Корректное исправление: универа
# Предсказание: уивера
#
# Реальное слово: отпразную	\	Корректное исправление: отпраздную
# Предсказание: отправную
#
# Реальное слово: отвечу	\	Корректное исправление: отвечу
# Предсказание: ответу
#
# Реальное слово: комменты	\	Корректное исправление: комменты
# Предсказание: коммуны
#
# Реальное слово: текилки	\	Корректное исправление: текилки
# Предсказание: кекилли
#
# Реальное слово: убеждены	\	Корректное исправление: убеждены
# Предсказание: убеждена
#
# Реальное слово: скзала	\	Корректное исправление: сказала
# Предсказание: скала
#
# Реальное слово: советую	\	Корректное исправление: советую
# Предсказание: совету
#
# Реальное слово: пасиб	\	Корректное исправление: спасибо
# Предсказание: насиб
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: рванина	\	Корректное исправление: рванина
# Предсказание: равнина
#
# Реальное слово: сос	\	Корректное исправление: со
# Предсказание: сос
#
# Реальное слово: встречавщимися	\	Корректное исправление: встречавшимися
# Предсказание: встречающимися
#
# Реальное слово: обогреваемый	\	Корректное исправление: обогреваемый
# Предсказание: обогреваемые
#
# Реальное слово: солнушком	\	Корректное исправление: солнышком
# Предсказание: солнышко
#
# Реальное слово: чтоы	\	Корректное исправление: чтобы
# Предсказание: что
#
# Реальное слово: насчт	\	Корректное исправление: насчет
# Предсказание: насчёт
#
# Реальное слово: меняемся	\	Корректное исправление: меняемся
# Предсказание: меняется
#
# Реальное слово: пронизтельно	\	Корректное исправление: пронзительно
# Предсказание: пронзительной
#
# Реальное слово: теперешний	\	Корректное исправление: теперешний
# Предсказание: теперешней
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: прописочкой	\	Корректное исправление: прописочкой
# Предсказание: прорисовкой
#
# Реальное слово: дошутилась	\	Корректное исправление: дошутилась
# Предсказание: докатилась
#
# Реальное слово: ждем	\	Корректное исправление: ждем
# Предсказание: ждет
#
# Реальное слово: напыщеные	\	Корректное исправление: напыщенные
# Предсказание: насыщенные
#
# Реальное слово: стискивают	\	Корректное исправление: стискивают
# Предсказание: отыскивают
#
# Реальное слово: прдолжаем	\	Корректное исправление: продолжаем
# Предсказание: продолжает
#
# Реальное слово: тока	\	Корректное исправление: только
# Предсказание: тока
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: пингу-понгу	\	Корректное исправление: пинг-понг
# Предсказание: пинг-понгом
#
# Реальное слово: разгребала	\	Корректное исправление: разгребала
# Предсказание: разрешала
#
# Реальное слово: творятся	\	Корректное исправление: творятся
# Предсказание: творится
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: сэкономили	\	Корректное исправление: сэкономили
# Предсказание: экономики
#
# Реальное слово: значет	\	Корректное исправление: значит
# Предсказание: знает
#
# Реальное слово: повозиться	\	Корректное исправление: повозиться
# Предсказание: проводиться
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: глюки	\	Корректное исправление: глюки
# Предсказание: люки
#
# Реальное слово: мещанский	\	Корректное исправление: мещанский
# Предсказание: мещанской
#
# Реальное слово: добавляю	\	Корректное исправление: добавляю
# Предсказание: добавляют
#
# Реальное слово: елку	\	Корректное исправление: елку
# Предсказание: ёлку
#
# Реальное слово: отдирла	\	Корректное исправление: отдирала
# Предсказание: отдела
#
# Реальное слово: бантики	\	Корректное исправление: бантики
# Предсказание: балтики
#
# Реальное слово: разворачивала	\	Корректное исправление: разворачивала
# Предсказание: разворачивал
#
# Реальное слово: извини	\	Корректное исправление: извини
# Предсказание: извинил
#
# Реальное слово: отыхаем	\	Корректное исправление: отдыхаем
# Предсказание: отдаем
#
# Реальное слово: садиков	\	Корректное исправление: садиков
# Предсказание: садчиков
#
# Реальное слово: прикольно	\	Корректное исправление: прикольно
# Предсказание: продольно
#
# Реальное слово: срочняком	\	Корректное исправление: срочняком
# Предсказание: сорняком
#
# Реальное слово: окей	\	Корректное исправление: окей
# Предсказание: осей
#
# Реальное слово: полюбому	\	Корректное исправление: по-любому
# Предсказание: полному
#
# Реальное слово: пересмотрю	\	Корректное исправление: пересмотрю
# Предсказание: пересмотр
#
# Реальное слово: огого	\	Корректное исправление: ого-го
# Предсказание: оного
#
# Реальное слово: захожу	\	Корректное исправление: захожу
# Предсказание: нахожу
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: погда	\	Корректное исправление: погода
# Предсказание: когда
#
# Реальное слово: установится	\	Корректное исправление: установится
# Предсказание: становится
#
# Реальное слово: доделаю	\	Корректное исправление: доделаю
# Предсказание: моделью
#
# Реальное слово: рекомундуемо	\	Корректное исправление: рекомендуемо
# Предсказание: рекомендуемое
#
# Реальное слово: ровно	\	Корректное исправление: равно
# Предсказание: ровно
#
# Реальное слово: тахту	\	Корректное исправление: тахту
# Предсказание: тарту
#
# Реальное слово: стеллаж	\	Корректное исправление: стеллаж
# Предсказание: стелла
#
# Реальное слово: появляюсь	\	Корректное исправление: появляюсь
# Предсказание: появляясь
#
# Реальное слово: шкворчать	\	Корректное исправление: шкварчать
# Предсказание: шкворчать
#
# Реальное слово: остально	\	Корректное исправление: остальное
# Предсказание: остальной
#
# Реальное слово: парикмахерском	\	Корректное исправление: парикмахерском
# Предсказание: парикмахерскому
#
# Реальное слово: огда	\	Корректное исправление: тогда
# Предсказание: года
#
# Реальное слово: саправедливыми	\	Корректное исправление: справедливыми
# Предсказание: справедливым…
#
# Реальное слово: межведомственная	\	Корректное исправление: межведомственная
# Предсказание: межведомственной
#
# Реальное слово: слезяться	\	Корректное исправление: слезятся
# Предсказание: смеяться
#
# ...
#
# Реальное слово: кивнули	\	Корректное исправление: кивнули
# Предсказание: кинули
#
# Реальное слово: рейсовыми	\	Корректное исправление: рейсовыми
# Предсказание: рейковыми
#
# Реальное слово: отуда	\	Корректное исправление: оттуда
# Предсказание: туда
#
# Реальное слово: байка	\	Корректное исправление: байка
# Предсказание: банка
#
# Реальное слово: ии	\	Корректное исправление: и
# Предсказание: ии
#
# Реальное слово: космополитеном	\	Корректное исправление: космополитеном
# Предсказание: космополитное
#
# Реальное слово: комнатки	\	Корректное исправление: комнатки
# Предсказание: комнатке
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: оказываецца	\	Корректное исправление: оказывается
# Предсказание: оказываемая
#
# Реальное слово: урбанист	\	Корректное исправление: урбанист
# Предсказание: органист
#
# Реальное слово: посочуствовали	\	Корректное исправление: посочувствовали
# Предсказание: способствовали
#
# Реальное слово: накинулись	\	Корректное исправление: накинулись
# Предсказание: начинались
#
# Реальное слово: курю	\	Корректное исправление: курю
# Предсказание: курс
#
# Реальное слово: порожке	\	Корректное исправление: порожке
# Предсказание: дорожке
#
# Реальное слово: милиционершу	\	Корректное исправление: милиционершу
# Предсказание: милиционеры
#
# Реальное слово: спрашиваю	\	Корректное исправление: спрашиваю
# Предсказание: спрашивал
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: поспшь	\	Корректное исправление: поспишь
# Предсказание: посеешь
#
# Реальное слово: непонятнх	\	Корректное исправление: непонятных
# Предсказание: непонятно
#
# Реальное слово: объяснала	\	Корректное исправление: объясняла
# Предсказание: объяснила
#
# Реальное слово: началнице	\	Корректное исправление: начальнице
# Предсказание: начальнике
#
# Реальное слово: играючи	\	Корректное исправление: играючи
# Предсказание: играли
#
# Реальное слово: вплетал	\	Корректное исправление: вплетал
# Предсказание: вылетал
#
# Реальное слово: покажутся	\	Корректное исправление: покажутся
# Предсказание: окажутся
#
# Реальное слово: куску	\	Корректное исправление: куску
# Предсказание: куско
#
# Реальное слово: бомжи	\	Корректное исправление: бомжи
# Предсказание: божи
#
# Реальное слово: банкроты	\	Корректное исправление: банкроты
# Предсказание: банкноты
#
# Реальное слово: юзаю	\	Корректное исправление: юзаю
# Предсказание: юза
#
# Реальное слово: юзать	\	Корректное исправление: юзать
# Предсказание: мать
#
# Реальное слово: стисняюсь	\	Корректное исправление: стесняюсь
# Предсказание: стесняясь
#
# Реальное слово: стемнело	\	Корректное исправление: стемнело
# Предсказание: сембелло
#
# Реальное слово: дооолго	\	Корректное исправление: долго
# Предсказание: дорого
#
# Реальное слово: остаецца	\	Корректное исправление: остается
# Предсказание: останца
#
# Реальное слово: смириццо	\	Корректное исправление: смириться
# Предсказание: смириццо
#
# Реальное слово: бороццо	\	Корректное исправление: бороться
# Предсказание: борово
#
# Реальное слово: 4.60	\	Корректное исправление: 4.60
# Предсказание: 460
#
# Реальное слово: што	\	Корректное исправление: что
# Предсказание: што
#
# Реальное слово: полнеба	\	Корректное исправление: полнеба
# Предсказание: погреба
#
# Реальное слово: чорный	\	Корректное исправление: черный
# Предсказание: чёрный
#
# Реальное слово: мууультики	\	Корректное исправление: мультики
# Предсказание: мууультики
#
# Реальное слово: вернууулась	\	Корректное исправление: вернулась
# Предсказание: отвернулась
#
# Реальное слово: рааада	\	Корректное исправление: рaда
# Предсказание: рашада
#
# Реальное слово: распыленные	\	Корректное исправление: распыленные
# Предсказание: распиленных
#
# Реальное слово: возьмешь	\	Корректное исправление: возьмешь
# Предсказание: возьмет
#
# Реальное слово: напишут	\	Корректное исправление: напишут
# Предсказание: напишет
#
# Реальное слово: оббрызгивается	\	Корректное исправление: обрызгивается
# Предсказание: оббрызгивается
#
# Реальное слово: дешевыми	\	Корректное исправление: дешевыми
# Предсказание: дешевым
#
# Реальное слово: планируем	\	Корректное исправление: планируем
# Предсказание: планирует
#
# Реальное слово: развицо	\	Корректное исправление: развиться
# Предсказание: развито
#
# Реальное слово: молчат	\	Корректное исправление: молчат
# Предсказание: молча
#
# Реальное слово: проверяю	\	Корректное исправление: проверяю
# Предсказание: проверяя
#
# Реальное слово: трата	\	Корректное исправление: трата
# Предсказание: брата
#
# Реальное слово: абоpигенку	\	Корректное исправление: аборигенку
# Предсказание: абоpигенку
#
# Реальное слово: пpиезжей	\	Корректное исправление: приезжей
# Предсказание: проезжей
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: грабель	\	Корректное исправление: грабель
# Предсказание: габель
#
# Реальное слово: свершениям	\	Корректное исправление: свершениям
# Предсказание: свершения
#
# Реальное слово: blanca	\	Корректное исправление: blanca
# Предсказание: blanco
#
# Реальное слово: поеште	\	Корректное исправление: поешьте
# Предсказание: пеште
#
# Реальное слово: нащет	\	Корректное исправление: насчет
# Предсказание: налет
#
# Реальное слово: yкладываются	\	Корректное исправление: yкладываются
# Предсказание: складываются
#
# Реальное слово: тоpмозные	\	Корректное исправление: тоpмозные
# Предсказание: тормозные
#
# Реальное слово: котоpых	\	Корректное исправление: котоpых
# Предсказание: которых
#
# Реальное слово: артурчик	\	Корректное исправление: артурчик
# Предсказание: астурика
#
# Реальное слово: сестрицы	\	Корректное исправление: сестрицы
# Предсказание: лестницы
#
# Реальное слово: ни	\	Корректное исправление: не
# Предсказание: ни
#
# Реальное слово: пискнул	\	Корректное исправление: пискнул
# Предсказание: рискнул
#
# Реальное слово: мамином	\	Корректное исправление: мамином
# Предсказание: марином
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: потресающия	\	Корректное исправление: потрясающая
# Предсказание: потрясающие
#
# Реальное слово: преподовательница	\	Корректное исправление: преподавательница
# Предсказание: преподавательницы
#
# Реальное слово: кошшшшка	\	Корректное исправление: кошка
# Предсказание: кошшшшка
#
# Реальное слово: становлюсь	\	Корректное исправление: становлюсь
# Предсказание: остановлюсь
#
# Реальное слово: человеколюбивее	\	Корректное исправление: человеколюбивее
# Предсказание: человеколюбивый
#
# Реальное слово: седня	\	Корректное исправление: сегодня
# Предсказание: седая
#
# Реальное слово: применяю	\	Корректное исправление: применяю
# Предсказание: применяют
#
# Реальное слово: срываюсь	\	Корректное исправление: срываюсь
# Предсказание: срываясь
#
# Реальное слово: блеклым	\	Корректное исправление: блеклым
# Предсказание: блеклые
#
# Реальное слово: желаньем	\	Корректное исправление: желаньем
# Предсказание: желанием
#
# Реальное слово: контакти	\	Корректное исправление: контакте
# Предсказание: контакт
#
# Реальное слово: нукда	\	Корректное исправление: никуда
# Предсказание: нужда
#
# Реальное слово: поперлась	\	Корректное исправление: поперлась
# Предсказание: потерялась
#
# Реальное слово: адресую	\	Корректное исправление: адресую
# Предсказание: адресу
#
# Реальное слово: барракуду	\	Корректное исправление: барракуду
# Предсказание: барракуд
#
# Реальное слово: созваниваемся	\	Корректное исправление: созваниваемся
# Предсказание: созванивается
#
# Реальное слово: выхватом	\	Корректное исправление: выхватом
# Предсказание: захватом
#
# Реальное слово: успевания	\	Корректное исправление: успевания
# Предсказание: отпевания
#
# Реальное слово: пробкам	\	Корректное исправление: пробкам
# Предсказание: пробках
#
# Реальное слово: минутам	\	Корректное исправление: минутам
# Предсказание: минута
#
# Реальное слово: какие	\	Корректное исправление: какие-то
# Предсказание: какие
#
# Реальное слово: то	\	Корректное исправление: плотники
# Предсказание: то
#
# Реальное слово: плотники	\	Корректное исправление: объясняя
# Предсказание: плотники
#
# Реальное слово: объясняя	\	Корректное исправление: экзаменатору
# Предсказание: объясняя
#
# Реальное слово: экзаменатору	\	Корректное исправление: что
# Предсказание: экзаменатору
#
# Реальное слово: что	\	Корректное исправление: связались
# Предсказание: что
#
# Реальное слово: связались	\	Корректное исправление: с
# Предсказание: связались
#
# Реальное слово: с	\	Корректное исправление: ней
# Предсказание: с
#
# Реальное слово: ней	\	Корректное исправление: через
# Предсказание: ней
#
# Реальное слово: через	\	Корректное исправление: емайл
# Предсказание: через
#
# Реальное слово: емайл	\	Корректное исправление: говорилось
# Предсказание: майкл
#
# Реальное слово: говорилось	\	Корректное исправление: о
# Предсказание: говорилось
#
# Реальное слово: о	\	Корректное исправление: заборе
# Предсказание: о
#
# Реальное слово: заборе	\	Корректное исправление: который
# Предсказание: заборе
#
# Реальное слово: который	\	Корректное исправление: не
# Предсказание: который
#
# Реальное слово: не	\	Корректное исправление: закрывается
# Предсказание: не
#
# Реальное слово: закрывается	\	Корректное исправление: затем
# Предсказание: закрывается
#
# Реальное слово: затем	\	Корректное исправление: зашла
# Предсказание: затем
#
# Реальное слово: зашла	\	Корректное исправление: не
# Предсказание: зашла
#
# Реальное слово: незнаю	\	Корректное исправление: знаю
# Предсказание: ненад
#
# Реальное слово: инете	\	Корректное исправление: инете
# Предсказание: инте
#
# Реальное слово: ничо	\	Корректное исправление: ничего
# Предсказание: нико
#
# Реальное слово: иво	\	Корректное исправление: его
# Предсказание: иво
#
# Реальное слово: шоколаде	\	Корректное исправление: шоколаде
# Предсказание: шоколада
#
# Реальное слово: связываем	\	Корректное исправление: связываем
# Предсказание: связывает
#
# Реальное слово: заразил	\	Корректное исправление: заразил
# Предсказание: выразил
#
# Реальное слово: компы	\	Корректное исправление: компы
# Предсказание: комы
#
# Реальное слово: запятых	\	Корректное исправление: запятых
# Предсказание: занятых
#
# Реальное слово: матерные	\	Корректное исправление: матерные
# Предсказание: матерые
#
# Реальное слово: позабодтесь	\	Корректное исправление: позаботьтесь
# Предсказание: позабодтесь
#
# Реальное слово: пофоторафировав	\	Корректное исправление: пофотографировав
# Предсказание: пофоторафировав
#
# Реальное слово: волнующие	\	Корректное исправление: волнующие
# Предсказание: волнующее
#
# Реальное слово: ессно	\	Корректное исправление: естественно
# Предсказание: ясно
#
# Реальное слово: ваще	\	Корректное исправление: вообще
# Предсказание: чаще
#
# Реальное слово: постибалса	\	Корректное исправление: постебался
# Предсказание: постигала
#
# Реальное слово: сногсшибальной	\	Корректное исправление: сногсшибательной
# Предсказание: сногсшибальной
#
# Реальное слово: едкому	\	Корректное исправление: едкому
# Предсказание: редкому
#
# Реальное слово: аромату	\	Корректное исправление: аромату
# Предсказание: аромат
#
# Реальное слово: штабель	\	Корректное исправление: штабель
# Предсказание: табель
#
# Реальное слово: сумбур	\	Корректное исправление: сумбур
# Предсказание: сумбура
#
# Реальное слово: эта	\	Корректное исправление: это
# Предсказание: эта
#
# Реальное слово: девченки	\	Корректное исправление: девчонки
# Предсказание: шевченко
#
# Реальное слово: заливаюсь	\	Корректное исправление: заливаюсь
# Предсказание: заливают
#
# Реальное слово: глянули	\	Корректное исправление: глянули
# Предсказание: грянули
#
# Реальное слово: стасу	\	Корректное исправление: стасу
# Предсказание: стану
#
# Реальное слово: ливня	\	Корректное исправление: ливня
# Предсказание: ливия
#
# Реальное слово: мыле	\	Корректное исправление: мыле
# Предсказание: мысе
#
# Реальное слово: пыраюсь	\	Корректное исправление: пытаюсь
# Предсказание: пытаясь
#
# Реальное слово: нарезает	\	Корректное исправление: нарезает
# Предсказание: нарезают
#
# Реальное слово: непридвиденные	\	Корректное исправление: непредвиденные
# Предсказание: непредвиденное
#
# Реальное слово: поздрваляю	\	Корректное исправление: поздравляю
# Предсказание: поздравляют
#
# Реальное слово: грю	\	Корректное исправление: говорю
# Предсказание: дрю
#
# Реальное слово: ничо	\	Корректное исправление: ничего
# Предсказание: нико
#
# Реальное слово: хотеццо	\	Корректное исправление: хотеться
# Предсказание: хотело
#
# Реальное слово: убиться	\	Корректное исправление: убиться
# Предсказание: учиться
#
# Реальное слово: веником	\	Корректное исправление: веником
# Предсказание: великом
#
# Реальное слово: плинтуса	\	Корректное исправление: плинтуса
# Предсказание: плинтусах
#
# Реальное слово: нравиццо	\	Корректное исправление: нравится
# Предсказание: нравиццо
#
# Реальное слово: посдравляю	\	Корректное исправление: поздравляю
# Предсказание: поздравляют
#
# Реальное слово: ооочень	\	Корректное исправление: очень
# Предсказание: …очень
#
# Реальное слово: погда	\	Корректное исправление: погода
# Предсказание: когда
#
# Реальное слово: осеннему	\	Корректное исправление: осеннему
# Предсказание: осенней
#
# Реальное слово: кааак	\	Корректное исправление: как
# Предсказание: казак
#
# Реальное слово: каааак	\	Корректное исправление: как
# Предсказание: казак
#
# Реальное слово: неискренное	\	Корректное исправление: неискреннее
# Предсказание: неискреннего
#
# Реальное слово: воооот	\	Корректное исправление: вот
# Предсказание: ворот
#
# Реальное слово: саб	\	Корректное исправление: саб
# Предсказание: сам
#
# Реальное слово: понаобещщал	\	Корректное исправление: понаобещал
# Предсказание: понаобещщал
#
# Реальное слово: запариваться	\	Корректное исправление: запариваться
# Предсказание: спариваться
#
# Реальное слово: неуравновешено	\	Корректное исправление: неуравновешенно
# Предсказание: неуравновешен
#
# Реальное слово: центрм	\	Корректное исправление: центром
# Предсказание: центр
#
# Реальное слово: вильно	\	Корректное исправление: сильно
# Предсказание: вильно
#
# Реальное слово: влева	\	Корректное исправление: влево
# Предсказание: слева
#
# Реальное слово: рассказжу	\	Корректное исправление: расскажу
# Предсказание: рассказу
#
# Реальное слово: покажиииии	\	Корректное исправление: покажи
# Предсказание: покажиииии
#
# Реальное слово: поженаем	\	Корректное исправление: пожинаем
# Предсказание: пожелает
#
# Реальное слово: забегаю	\	Корректное исправление: забегаю
# Предсказание: забегах
#
# Реальное слово: болтаю	\	Корректное исправление: болтаю
# Предсказание: болта
#
# Реальное слово: девочнками	\	Корректное исправление: девчонками
# Предсказание: девочками
#
# Реальное слово: радужном	\	Корректное исправление: радужном
# Предсказание: радужной
#
# Реальное слово: маршрутки	\	Корректное исправление: маршрутки
# Предсказание: маршрутка
#
# Реальное слово: финбана	\	Корректное исправление: финбана
# Предсказание: финала
#
# Реальное слово: толкаться	\	Корректное исправление: толкаться
# Предсказание: чокаться
#
# Реальное слово: торбой	\	Корректное исправление: торбой
# Предсказание: тобой
#
# Реальное слово: 1930-ые	\	Корректное исправление: 1930-ые
# Предсказание: 1930-е
#
# Реальное слово: собсно	\	Корректное исправление: собственно
# Предсказание: соосно
#
# Реальное слово: апять	\	Корректное исправление: опять
# Предсказание: пять
#
# Реальное слово: мной	\	Корректное исправление: мне
# Предсказание: мной
#
# Реальное слово: будеш	\	Корректное исправление: будешь
# Предсказание: будет
#
# Реальное слово: сваи	\	Корректное исправление: свои
# Предсказание: сваи
#
# Реальное слово: аписывать	\	Корректное исправление: описывать
# Предсказание: записывать
#
# Реальное слово: шоб	\	Корректное исправление: чтоб
# Предсказание: об
#
# Реальное слово: рассчет	\	Корректное исправление: расчет
# Предсказание: рассвет
#
# Реальное слово: берем	\	Корректное исправление: берем
# Предсказание: берег
#
# Реальное слово: ничо	\	Корректное исправление: ничего
# Предсказание: нико
#
# Реальное слово: совлаладав	\	Корректное исправление: совладав
# Предсказание: совлаладав
#
# Реальное слово: тусуется	\	Корректное исправление: тусуется
# Предсказание: рисуется
#
# Реальное слово: прочитавшие	\	Корректное исправление: прочитавшие
# Предсказание: прочитавший
#
# Реальное слово: жизни	\	Корректное исправление: жизнь
# Предсказание: жизни
#
# Реальное слово: денется	\	Корректное исправление: денется
# Предсказание: дерется
#
# Реальное слово: подворотни	\	Корректное исправление: подворотни
# Предсказание: поворотный
#
# Реальное слово: лязгом	\	Корректное исправление: лязгом
# Предсказание: мозгом
#
# Реальное слово: собссно	\	Корректное исправление: собственно
# Предсказание: собрано
#
# Реальное слово: готовься	\	Корректное исправление: готовься
# Предсказание: готовится
#
# Реальное слово: подешевеет	\	Корректное исправление: подешевеет
# Предсказание: подешевле
#
# Реальное слово: квартирку	\	Корректное исправление: квартирку
# Предсказание: квартиру

# %% [markdown]
# Еще я хотела попробовать использовать взвешенную метрику Левенштейна с параметрами опечаток на клавиатуре

# %%
transpose_costs = np.ones((32, 32))

# %%
# я хотела использовать библиотеку библиотеку но там для кириллических символов не подходит
# поэтому DP функция украденная из интернета и чуток доработанная

def sub_cost_matrix(a, b, costs):
    idx_a = ord(a) - 1072
    idx_b = ord(b) - 1072

    if 0 <= idx_a < costs.shape[0] and 0 <= idx_b < costs.shape[1]:
        return costs[idx_a, idx_b]
    else:
        return 2.0


import numpy as np

def weighted_damerau_levenshtein(s1, s2, costs):
    n, m = len(s1), len(s2)
    dp = np.zeros((n+1, m+1), dtype=float)

    for i in range(n+1):
        dp[i][0] = i
    for j in range(m+1):
        dp[0][j] = j

    for i in range(1, n+1):
        for j in range(1, m+1):
            cost = sub_cost_matrix(s1[i-1], s2[j-1], costs)
            dp[i][j] = min(
                dp[i-1][j] + 1,        # удаление
                dp[i][j-1] + 1,        # вставка
                dp[i-1][j-1] + cost    # замена
            )
            # транспозиция
            if i>1 and j>1 and s1[i-1]==s2[j-2] and s1[i-2]==s2[j-1]:
                dp[i][j] = min(dp[i][j], dp[i-2][j-2] + 0.5)

    return dp[n][m]

# %%
keyboard_pos = {
    'й': (0, 0), 'ц': (0, 1), 'у': (0, 2), 'к': (0, 3), 'е': (0, 4),
    'н': (0, 5), 'г': (0, 6), 'ш': (0, 7), 'щ': (0, 8), 'з': (0, 9), 'х': (0, 10),

    'ф': (1, 0), 'ы': (1, 1), 'в': (1, 2), 'а': (1, 3), 'п': (1, 4),
    'р': (1, 5), 'о': (1, 6), 'л': (1, 7), 'д': (1, 8), 'ж': (1, 9), 'э': (1, 10),

    'я': (2, 1), 'ч': (2, 2), 'с': (2, 3), 'м': (2, 4), 'и': (2, 5),
    'т': (2, 6), 'ь': (2, 7), 'б': (2, 8), 'ю': (2, 9)
}

# %%
import math

def key_distance(a, b, keyboard_pos):
    if a not in keyboard_pos or b not in keyboard_pos:
        return 1.0
    (r1, c1) = keyboard_pos[a]
    (r2, c2) = keyboard_pos[b]
    # евклидова метрика
    return math.sqrt((r1 - r2)**2 + (c1 - c2)**2)

# %%
costs = np.ones((32, 32), dtype=np.float64)
for i in range(1072, 1104):
    for j in range(1072, 1104):
        dist = key_distance(chr(i), chr(j), keyboard_pos=keyboard_pos)
        costs[abs(1072-i), abs(1072-j)] = dist

# %%
y_true_end = []
y_actual_end = []
y_preds_end = []

for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])

    corrected = correct_text_with_symspell_morph(bad[i], dictionary, deletion_index, max_distance=3, weight=costs).split()

    for j in range(len(word_pairs)):
        true_word = word_pairs[j][0]
        actual_word = word_pairs[j][1]
        pred = corrected[j]

        y_true_end.append(true_word)
        y_actual_end.append(actual_word)
        y_preds_end.append(pred)
# Out:
# 100%|██████████| 915/915 [02:17<00:00,  6.64it/s]

# %%
metrics = calculate_metrics(y_true_end, y_actual_end, y_preds_end)
metrics
# Out:
# {'total_accuracy': 0.8663331665832916,
#  'fixed_mistakes': 0.3579192546583851,
#  'broken_correct_words': 0.058458711381646954}

# %% [markdown]
# Качество ухудшилось... можно попробовать фонетическую модель, что в принципе по данным похоже, что ошибки именно из-за того, что люди пишут так же, как и слышат...
#
# После поисков по этой тематике я наткнулась на работу Сорокина и Шавриной 2016 (https://www.researchgate.net/publication/303813582_Automatic_spelling_correction_for_Russian_social_media_texts), поэтому данные по фонетическим классам взяла оттуда

# %%
phonetic_classes = {
    1:  "а о ы у я",      
    3:  "и е ё ю я э",    
    5:  "б п",
    6:  "в ф",
    7:  "д т",
    8:  "г к х",
    9:  "л",
    10: "р",
    11: "м",
    12: "н",
    13: "з с",
    14: "й",
    15: "щ ч",
    16: "ж ш",
    17: "ц"
}

groups = {
    "vowels": {1,3},
    "labials": {5,6},
    "dentals": {7,13,17},
    "palatals": {14,15},
    "velars": {8},
    "liquids": {9,10},
    "nasals": {11,12},
    "shush": {16},
}

# %%
letter_to_classes = {}

for cls, letters in phonetic_classes.items():
    for letter in letters.split():
        letter_to_classes.setdefault(letter, set()).add(cls)

# %%
def phonetic_sub_cost(a, b):
    if a == b:
        return 0.0
    
    cls_a = letter_to_classes.get(a, set())
    cls_b = letter_to_classes.get(b, set())
    
    if not cls_a or not cls_b:
        return 1.0
    
    if cls_a & cls_b:
        return 0.2
    
    for grp, members in groups.items():
        if cls_a.issubset(members) and cls_b.issubset(members):
            return 0.7
    
    return 1.0

# %%
alphabet = [chr(i) for i in range(1072, 1104)]

sub_costs = np.zeros((32, 32), dtype=np.float64)

for i, c1 in enumerate(alphabet):
    for j, c2 in enumerate(alphabet):
        sub_costs[i, j] = phonetic_sub_cost(c1, c2)

# %%
y_true_phone = []
y_actual_phone = []
y_preds_phone = []

for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])

    corrected = correct_text_with_symspell_morph(bad[i], dictionary, deletion_index, max_distance=3, weight=sub_costs).split()

    for j in range(len(word_pairs)):
        true_word = word_pairs[j][0]
        actual_word = word_pairs[j][1]
        pred = corrected[j]

        y_true_phone.append(true_word)
        y_actual_phone.append(actual_word)
        y_preds_phone.append(pred)
# Out:
# 100%|██████████| 915/915 [02:13<00:00,  6.85it/s]

# %%
metrics = calculate_metrics(y_true_end, y_actual_phone, y_preds_phone)
metrics
# Out:
# {'total_accuracy': 0.8649324662331166,
#  'fixed_mistakes': 0.5015527950310559,
#  'broken_correct_words': 0.08131388537957965}

# %%
# если комбинировать...
def candidate_score(input_word, candidate, dictionary, weight=None, ending=False):
    freq = dictionary.get(candidate, 0)
    gm = grammar_match(input_word, candidate, ending=ending)
    dist =  textdistance.damerau_levenshtein(input_word, candidate)
    phone_dist = weighted_damerau_levenshtein(input_word, candidate, costs=weight)

    score = (candidate, dist+phone_dist/2, freq, gm)
    return score

# %%
y_true_phone = []
y_actual_phone = []
y_preds_phone = []

for i in tqdm(range(len(true))):
    word_pairs = align_words(true[i], bad[i])

    corrected = correct_text_with_symspell_morph(bad[i], dictionary, deletion_index, max_distance=3, weight=sub_costs).split()

    for j in range(len(word_pairs)):
        true_word = word_pairs[j][0]
        actual_word = word_pairs[j][1]
        pred = corrected[j]

        y_true_phone.append(true_word)
        y_actual_phone.append(actual_word)
        y_preds_phone.append(pred)
# Out:
# 100%|██████████| 915/915 [02:20<00:00,  6.54it/s]

# %%
metrics = calculate_metrics(y_true_end, y_actual_phone, y_preds_phone)
metrics
# Out:
# {'total_accuracy': 0.8701350675337669,
#  'fixed_mistakes': 0.5419254658385093,
#  'broken_correct_words': 0.08131388537957965}

# %% [markdown]
# Я пробовала разные комбинации, но результаты дало только небольшое добавление морфологии + добавлению в дистанцию транспозиции классической. Причем, когда я делала полноценную фильтрацию, где отбрасывала кандидатов, нарушающие разные признаки оригинального слова, – результаты становились даже хуже, чем при самом обычно SymSpell. Итого у улучшенной результат лучше только на 12 пунктов, but it was fun.
